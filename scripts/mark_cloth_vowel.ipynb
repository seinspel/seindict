# %%
import re
from utils import apply

# %%
cloth_environs = ("TH", "F", "S", "NG", "G", "K", "N", "SH")
thought = ("AO0", "AO1", "AO2")

# %%
overrides = {
    # things that are just wrong
    "BLOGOSPHERE": "B L OO1 G AX S F IH1 R",
    'OCCASION': 'AX K EY1 ZH AX N',
    'OCCASIONAL': 'AX K EY1 ZH AX N AX L',
    "QUASH": "K W AA1 SH",
    
}

exclude = """
COAUTHOR
""".split()

def change_to_cloth_vowel(word, pronun, dictionary):
    if word in overrides:
        return overrides[word]
    
    if word in exclude:
        return True

    o_indices = []
    # replace digraphs with single letters so that the index calculation is more reliable
    word_with_better_letters = word.replace("SH", "ʃ").replace("TH", "θ").replace("WH", "ʍ").replace("CH", "ʒ")
    for combo, offset in (("O", 0), ("WA(?![UWL])", 1), ("QUA(?![UWL])", 2)):
        o_indices += [m.start() + offset for m in re.finditer(combo, word_with_better_letters)]
            
    if not o_indices:  # no suitable letters found
        return True
    
    present_stresses = []
    for vowel in thought:
        if any(f"{vowel} {environ}" in pronun for environ in cloth_environs):
            stress = vowel[-1]
#             if f"AO{stress} SH" in pronun:
#                 print(f"SH is not a valid environment: '{word}'")
#                 continue
            present_stresses.append(stress)
    if not present_stresses:
        return True
    
#     num_o = len([m.start() for m in re.finditer('O', word)])
#     if num_o > 1 and len(present_stresses) > 1:
#         print(f"More than one O: \"{word}\": \"{pronun}\",")
#     return True

    leeway = 2 if len(present_stresses) == 1 else 1  # if there is more than one AO, don't get them mixed up

    changed_anything = False
    new_pronun = pronun
    for stress in present_stresses:
        vowel = f"AO{stress}"
        ao_index = new_pronun.split().index(vowel)
        if min(abs(o_index - ao_index) for o_index in o_indices) > leeway:
#             print(f"probably no candiate '{word}', letter indices: {o_indices}, sound index: {ao_index}")
            continue
        new_pronun = new_pronun.replace(vowel, f"OO{stress}")
        changed_anything = True
    if not changed_anything:
        return True
    print(f"change '{word.lower().replace('o', 'O')}', new pronun: '{new_pronun.lower().replace('oo', 'OO')}'")
    return new_pronun

# %%
apply(
    change_to_cloth_vowel,
    save_result=True,
    only_first_file=False,
    mode="transform",
)
# Out:
# change 'abendrOth', new pronun: 'ae1 b ih0 n d r OO0 th'
# change 'absecOn', new pronun: 'ae1 b s ax k OO0 n'
# change 'accOst', new pronun: 'ax k OO1 s t'
# change 'accOsted', new pronun: 'ax k OO1 s t ih0 d'
# change 'acOg', new pronun: 'ax k OO1 g'
# change 'acOsta', new pronun: 'ax k OO1 s t ax'
# change 'acrOss', new pronun: 'ax k r OO1 s'
# change 'adOn', new pronun: 'aa0 d OO1 n'
# change 'agOstinO', new pronun: 'aa0 g OO0 s t iy1 n ow0'
# change 'ahOskie', new pronun: 'ax hh OO1 s k iy0'
# change 'airlOck', new pronun: 'eh1 r l OO2 k'
# change 'alfOnse', new pronun: 'ae1 l f OO0 n s'
# change 'alfOnsO', new pronun: 'ae2 l f OO1 n s ow0'
# change 'alfOnzO', new pronun: 'ae2 l f OO1 n z ow0'
# change 'allbrittOn', new pronun: 'ao1 l b r ih0 t OO0 n'
# change 'alOft', new pronun: 'ax l OO1 f t'
# change 'alOng', new pronun: 'ax l OO1 ng'
# change 'alOngside', new pronun: 'ax l OO1 ng s ay1 d'
# change 'altamOnt', new pronun: 'aa1 l t ax m OO2 n t'
# change 'alteOn', new pronun: 'aa1 l t iy0 OO0 n'
# change 'althOff', new pronun: 'ae1 l t hh OO0 f'
# change 'amerOngen', new pronun: 'ae2 m axr OO1 n jh ax n'
# change 'amOn', new pronun: 'aa0 m OO1 n'
# change 'amOss', new pronun: 'ax m OO1 s'
# change 'amOxicillin', new pronun: 'ax m OO1 k s ih0 s ih2 l ih0 n'
# change 'amplicOns', new pronun: 'ae1 m p l ih0 k OO0 n z'
# change 'analOg', new pronun: 'ae1 n ax l OO2 g'
# change 'analOgue', new pronun: 'ae1 n ax l OO2 g'
# change 'aniOn', new pronun: 'ae1 n ay2 OO0 n'
# change 'anOn', new pronun: 'ax n OO1 n'
# change 'anOpheles', new pronun: 'ae0 n OO1 f ih0 l iy2 z'
# change 'anthOny', new pronun: 'ae1 n th OO0 n iy0'
# change 'antOn', new pronun: 'ae1 n t OO2 n'
# change 'apOstate', new pronun: 'ax p OO1 s t ey0 t'
# change 'apOstle', new pronun: 'ax p OO1 s ax l'
# change 'apOstOl', new pronun: 'ae1 p OO0 s t ax l'
# change 'apOstOlic', new pronun: 'ae2 p OO0 s t aa1 l ih0 k'
# change 'apOstrOphe', new pronun: 'ax p OO1 s t r ax f iy0'
# change 'aristOphanes', new pronun: 'eh2 r ax s t OO1 f ax n iy0 z'
# change 'armacOst', new pronun: 'aa1 r m ax k OO2 s t'
# change 'armstrOng', new pronun: 'aa1 r m s t r OO2 ng'
# change 'arOnOff', new pronun: 'eh1 r ax n OO0 f'
# change 'ashcrOft', new pronun: 'ae1 sh k r OO2 f t'
# change 'avignOn', new pronun: 'ae1 v ih0 n y OO2 n'
# changed 44 entries in A.yaml
# change 'babcOck', new pronun: 'b ae1 b k OO0 k'
# change 'backlOg', new pronun: 'b ae1 k l OO2 g'
# change 'backlOgged', new pronun: 'b ae1 k l OO2 g d'
# change 'bahnhOf', new pronun: 'b aa2 n hh OO1 f'
# change 'balOg', new pronun: 'b ae1 l OO0 g'
# change 'balOn', new pronun: 'b aa0 l OO1 n'
# change 'bancrOft', new pronun: 'b ae1 ng k r OO0 f t'
# change 'bancrOft's', new pronun: 'b ae1 ng k r OO2 f t ' s'
# change 'baranOwski', new pronun: 'b axr ax n OO1 f s k iy0'
# change 'barcrOft', new pronun: 'b aa1 r k r OO2 f t'
# change 'bardOn', new pronun: 'b aa0 r d OO1 n'
# change 'bartkOwski', new pronun: 'b axr t k OO1 f s k iy0'
# change 'beaumOnt', new pronun: 'b ow1 m OO0 n t'
# change 'beecrOft', new pronun: 'b iy1 k r OO2 f t'
# change 'belOff', new pronun: 'b eh1 l OO2 f'
# change 'belOng', new pronun: 'b ih0 l OO1 ng'
# change 'benettOn', new pronun: 'b eh1 n ax t OO0 n'
# change 'bergerOn', new pronun: 'b er1 g axr OO0 n'
# change 'berghOf', new pronun: 'b er1 g hh OO0 f'
# change 'berghOff', new pronun: 'b er1 g hh OO0 f'
# change 'berkOff', new pronun: 'b er1 k OO0 f'
# change 'beschlOss', new pronun: 'b eh1 sh l OO2 s'
# change 'beschlOss's', new pronun: 'b eh1 sh l OO2 s ih0 ' s'
# change 'beyOnce', new pronun: 'b ih0 y OO1 n s ey0'
# change 'beyOnd', new pronun: 'b ih0 y OO1 n d'
# change 'bhOsle', new pronun: 'b OO1 s ax l'
# change 'bichOn', new pronun: 'b iy2 sh OO1 n'
# change 'biOnic', new pronun: 'b ay2 OO1 n ih0 k'
# change 'birdsOng', new pronun: 'b er1 d s OO2 ng'
# change 'birkhOff', new pronun: 'b er1 k hh OO0 f'
# change 'bischOff', new pronun: 'b ih1 s k hh OO0 f'
# change 'bishOff', new pronun: 'b ih1 s hh OO0 f'
# change 'blastOff', new pronun: 'b l ae1 s t OO2 f'
# change 'blOg', new pronun: 'b l OO1 g'
# change 'blOgger', new pronun: 'b l OO1 g axr'
# change 'blOgging', new pronun: 'b l OO1 g ih0 ng'
# change 'blOss', new pronun: 'b l OO1 s'
# change 'blOsser', new pronun: 'b l OO1 s axr'
# change 'bObrOwski', new pronun: 'b ax b r OO1 f s k iy0'
# change 'bOff', new pronun: 'b OO1 f'
# change 'bOffO', new pronun: 'b OO1 f ow0'
# change 'bOg', new pronun: 'b OO1 g'
# change 'bOgged', new pronun: 'b OO1 g d'
# change 'bOgging', new pronun: 'b OO1 g ih0 ng'
# change 'bOggs', new pronun: 'b OO1 g z'
# change 'bOllOcks', new pronun: 'b aa1 l OO0 k s'
# change 'bOngers', new pronun: 'b OO1 ng axr z'
# change 'bOnner', new pronun: 'b OO1 n axr'
# change 'bOnnes', new pronun: 'b OO1 n z'
# change 'bOrkOwski', new pronun: 'b axr k OO1 f s k iy0'
# change 'bOrOwski', new pronun: 'b axr OO1 f s k iy0'
# change 'bOsch', new pronun: 'b OO1 sh'
# change 'bOschert', new pronun: 'b OO1 sh axr t'
# change 'bOschwitz', new pronun: 'b OO1 sh w ih0 t s'
# change 'bOscO', new pronun: 'b OO1 s k ow0'
# change 'bOskin', new pronun: 'b OO1 s k ih0 n'
# change 'bOss', new pronun: 'b OO1 s'
# change 'bOsses', new pronun: 'b OO1 s ih0 z'
# change 'bOssidy', new pronun: 'b OO1 s ih0 d iy0'
# change 'bOssie', new pronun: 'b OO1 s iy0'
# change 'bOssier', new pronun: 'b OO1 s iy0 axr'
# change 'bOssman', new pronun: 'b OO1 s m ax n'
# change 'bOssy', new pronun: 'b OO1 s iy0'
# change 'bOstOn', new pronun: 'b OO1 s t ax n'
# change 'bOstOnian', new pronun: 'b OO2 s t ow1 n iy0 ax n'
# change 'bOstOnians', new pronun: 'b OO1 s t ow0 n iy0 ax n z'
# change 'bOtOx', new pronun: 'b ow1 t OO2 k s'
# change 'brinkerhOff', new pronun: 'b r ih1 ng k axr hh OO2 f'
# change 'brOdOwski', new pronun: 'b r ax d OO1 f s k iy0'
# change 'brOntOsaurus', new pronun: 'b r OO2 n t ax s ao1 r ax s'
# change 'brOnwen', new pronun: 'b r OO1 n w ih0 n'
# change 'brOsch', new pronun: 'b r OO1 sh'
# change 'brOss', new pronun: 'b r OO1 s'
# change 'brOssman', new pronun: 'b r OO1 s m ax n'
# change 'brOth', new pronun: 'b r OO1 th'
# change 'brzOzOwski', new pronun: 'b r ax z OO1 f s k iy0'
# change 'budlOng', new pronun: 'b ah1 d l OO2 ng'
# change 'bukOwski', new pronun: 'b y uw0 k OO1 f s k iy0'
# change 'bulldOg', new pronun: 'b uh1 l d OO2 g'
# change 'bullfrOg', new pronun: 'b uh1 l f r OO2 g'
# change 'bushOng', new pronun: 'b uh1 sh OO0 ng'
# change 'bygOne', new pronun: 'b ay1 g OO2 n'
# changed 83 entries in B.yaml
# change 'cabletrOn', new pronun: 'k ey1 b ax l t r OO2 n'
# change 'calgOn', new pronun: 'k ae1 l g OO0 n'
# change 'carbOnic', new pronun: 'k aa0 r b OO1 n ih0 k'
# change 'carbOxylic', new pronun: 'k aa0 r b OO0 k s ih1 l ih0 k'
# change 'cardOn', new pronun: 'k aa0 r d OO1 n'
# change 'carOn', new pronun: 'k aa0 r OO1 n'
# change 'carreOn', new pronun: 'k aa0 r ey0 OO1 n'
# change 'catalOg', new pronun: 'k ae1 t ax l OO0 g'
# change 'catalOger', new pronun: 'k ae1 t ax l OO2 g axr'
# change 'catalOgue', new pronun: 'k ae1 t ax l OO2 g'
# change 'catalOgued', new pronun: 'k ae1 t ax l OO2 g d'
# change 'catalOguing', new pronun: 'k ae1 t ax l OO2 g ih0 ng'
# change 'cephalOspOrin', new pronun: 's eh2 f ax l OO1 s p ao2 r ih0 n'
# change 'chabOn', new pronun: 'sh aa0 b OO1 n'
# change 'chansOn', new pronun: 'sh aa1 n s OO2 n'
# change 'chavOus', new pronun: 'sh ax v OO1 s'
# change 'checkOff', new pronun: 'ch eh1 k OO2 f'
# change 'cheOng', new pronun: 'ch iy1 OO0 ng'
# change 'chernOff', new pronun: 'k er1 n OO0 f'
# change 'chillicOthe', new pronun: 'ch ih1 l ih0 k OO0 th'
# change 'chlebOwski', new pronun: 'ch l ih0 b OO1 f s k iy0'
# change 'chlebOwski', new pronun: 'k l ih0 b OO1 f s k iy0'
# change 'chOcOlate', new pronun: 'ch OO1 k l ax t'
# change 'chOng', new pronun: 'ch OO1 ng'
# change 'chOngqing', new pronun: 'ch OO1 ng k ih1 ng'
# change 'christOff', new pronun: 'k r ih1 s t OO0 f'
# change 'christOph', new pronun: 'k r ih1 s t OO0 f'
# change 'christOphe', new pronun: 'k r ih0 s t OO1 f'
# change 'chrzanOwski', new pronun: 'ch er2 z ax n OO1 f s k iy0'
# change 'cinnabOn', new pronun: 's ih1 n ax b OO2 n'
# change 'clOg', new pronun: 'k l OO1 g'
# change 'clOgged', new pronun: 'k l OO1 g d'
# change 'clOgging', new pronun: 'k l OO1 g ih0 ng'
# change 'clOss', new pronun: 'k l OO1 s'
# change 'clOsser', new pronun: 'k l OO1 s axr'
# change 'clOth', new pronun: 'k l OO1 th'
# change 'cOckamamie', new pronun: 'k OO2 k ax m ey1 m iy0'
# change 'cOffee', new pronun: 'k OO1 f iy0'
# change 'cOffeehOuse', new pronun: 'k OO1 f iy0 hh aw2 s'
# change 'cOffeehOuses', new pronun: 'k OO1 f iy0 hh aw2 s ih0 z'
# change 'cOffer', new pronun: 'k OO1 f axr'
# change 'cOffin', new pronun: 'k OO1 f ih0 n'
# change 'cOffing', new pronun: 'k OO1 f ih0 ng'
# change 'cOffman', new pronun: 'k OO1 f m ax n'
# change 'cOg', new pronun: 'k OO1 g'
# change 'cOgnOscenti', new pronun: 'k aa2 g n OO0 s eh1 n t iy0'
# change 'cOintreau', new pronun: 'k OO2 n t r ow1'
# change 'cOlOn', new pronun: 'k ow1 l OO0 n'
# change 'cOlOssal', new pronun: 'k ax l OO1 s ax l'
# change 'cOlOssus', new pronun: 'k ax l OO1 s ax s'
# change 'cOmpOstela', new pronun: 'k ao2 m p OO0 s t eh1 l ax'
# change 'cOncentrate', new pronun: 'k OO1 n s ax n t r ey2 t'
# change 'cOncentrated', new pronun: 'k OO1 n s ax n t r ey2 t ih0 d'
# change 'cOncentrating', new pronun: 'k OO1 n s ax n t r ey2 t ih0 ng'
# change 'cOncentratiOn', new pronun: 'k OO2 n s ax n t r ey1 sh ax n'
# change 'cOng', new pronun: 'k OO1 ng'
# change 'cOnga', new pronun: 'k OO1 ng g ax'
# change 'cOnger', new pronun: 'k OO1 ng axr'
# change 'cOngruence', new pronun: 'k OO1 ng g r uw0 ax n s'
# change 'cOngruent', new pronun: 'k OO1 ng g r uw0 ax n t'
# change 'cOngruity', new pronun: 'k OO0 ng g r uw1 ih0 t iy0'
# change 'cOnnie', new pronun: 'k OO1 n iy0'
# change 'cOnnOlly', new pronun: 'k OO1 n ax l iy0'
# change 'cOnrOy', new pronun: 'k OO1 n r oy0'
# change 'cOnte', new pronun: 'k OO1 n t'
# change 'cOnte', new pronun: 'k OO1 n t ey0'
# change 'cOntras', new pronun: 'k OO1 n t r ax z'
# change 'cOrsa', new pronun: 'k OO1 s ax'
# change 'cOs', new pronun: 'k OO1 s'
# change 'cOspOnsOr', new pronun: 'k ow2 s p OO1 n s axr'
# change 'cOss', new pronun: 'k OO1 s'
# change 'cOssa', new pronun: 'k OO1 s ax'
# change 'cOssack', new pronun: 'k OO1 s ax k'
# change 'cOst', new pronun: 'k OO1 s t'
# change 'cOsta', new pronun: 'k OO1 s t ax'
# change 'cOstabile', new pronun: 'k OO1 s t ax b ay2 l'
# change 'cOstcO', new pronun: 'k OO1 s t k ow0'
# change 'cOstellO', new pronun: 'k OO2 s t eh1 l ow0'
# change 'cOster', new pronun: 'k OO1 s t axr'
# change 'cOstlier', new pronun: 'k OO1 s t l iy0 axr'
# change 'cOstliest', new pronun: 'k OO1 s t l iy0 ih0 s t'
# change 'cOstlOw', new pronun: 'k OO1 s t l ow0'
# change 'cOstume', new pronun: 'k OO1 s t uw0 m'
# change 'cOstumed', new pronun: 'k OO1 s t uw2 m d'
# change 'cOstumer', new pronun: 'k OO1 s t uw0 m axr'
# change 'cOtyledOn', new pronun: 'k ao1 t ax l iy2 d OO0 n'
# change 'cOugh', new pronun: 'k OO1 f'
# change 'cOughenOur', new pronun: 'k OO0 f eh1 n axr'
# change 'cOughlan', new pronun: 'k OO1 g l ax n'
# change 'cOughlin', new pronun: 'k OO1 g l ih0 n'
# change 'cOunterOffensive', new pronun: 'k aw2 n t axr OO0 f eh1 n s ih0 v'
# change 'cOunterOffer', new pronun: 'k aw1 n t axr OO2 f axr'
# change 'cOupOn', new pronun: 'k uw1 p OO2 n'
# change 'cOutant', new pronun: 'k uw0 t OO1 n t'
# change 'crampOn', new pronun: 'k r ae1 m p OO0 n'
# change 'crisscrOss', new pronun: 'k r ih1 s k r OO2 s'
# change 'crOft', new pronun: 'k r OO1 f t'
# change 'crOs', new pronun: 'k r OO1 s'
# change 'crOss', new pronun: 'k r OO1 s'
# change 'crOssbill', new pronun: 'k r OO1 s b ih2 l'
# change 'crOssbOnes', new pronun: 'k r OO1 s b ow2 n z'
# change 'crOssbOrder', new pronun: 'k r OO1 s b ao2 r d axr'
# change 'crOssbOw', new pronun: 'k r OO1 s b ow0'
# change 'crOssen', new pronun: 'k r OO1 s ax n'
# change 'crOsser', new pronun: 'k r OO1 s axr'
# change 'crOsses', new pronun: 'k r OO1 s ih0 z'
# change 'crOssfield', new pronun: 'k r OO1 s f iy2 l d'
# change 'crOssfire', new pronun: 'k r OO1 s f ay0 axr'
# change 'crOssfire's', new pronun: 'k r OO1 s f ay0 r ' z'
# change 'crOssland', new pronun: 'k r OO1 s l ae2 n d'
# change 'crOssman', new pronun: 'k r OO1 s m ax n'
# change 'crOssOver', new pronun: 'k r OO1 s ow2 v axr'
# change 'crOsspieces', new pronun: 'k r OO1 s p iy2 s ih0 z'
# change 'crOssrOad', new pronun: 'k r OO1 s r ow2 d'
# change 'crOsstalk', new pronun: 'k r OO1 s t OO1 k'
# change 'crOsstOwn', new pronun: 'k r OO1 s t aw2 n'
# change 'crOsswise', new pronun: 'k r OO1 s w ay2 z'
# change 'crOsswOrd', new pronun: 'k r OO1 s w er2 d'
# change 'crOutOn', new pronun: 'k r uw1 t OO0 n'
# change 'cryOnics', new pronun: 'k r ay2 OO1 n ih0 k s'
# change 'cuOng', new pronun: 'k w OO1 ng'
# change 'cutOff', new pronun: 'k ah1 t OO2 f'
# change 'cyclOspOrine', new pronun: 's ih0 k l OO1 s p axr iy2 n'
# change 'czajkOwski', new pronun: 'ch ay0 k OO1 f s k iy0'
# changed 122 entries in C.yaml
# change 'dabrOwski', new pronun: 'd ax b r OO1 f s k iy0'
# change 'daikOn', new pronun: 'd ay1 k OO2 n'
# change 'damerOn', new pronun: 'd aa0 m eh0 r OO1 n'
# change 'davidOff', new pronun: 'd ey1 v ih0 d OO0 f'
# change 'davignOn', new pronun: 'd aa0 v iy0 g n OO1 n'
# change 'dayhOff', new pronun: 'd ey1 hh OO0 f'
# change 'daylOng', new pronun: 'd ey1 l OO2 ng'
# change 'decathlOn', new pronun: 'd iy0 k ae1 th l OO0 n'
# change 'defrOst', new pronun: 'd ih0 f r OO1 s t'
# change 'degrOff', new pronun: 'd eh1 g r OO0 f'
# change 'dejOng', new pronun: 'd ih0 jh OO1 ng'
# change 'delOng', new pronun: 'd ih0 l OO1 ng'
# change 'dialOg', new pronun: 'd ay1 ax l OO0 g'
# change 'dialOgue', new pronun: 'd ay1 ax l OO2 g'
# change 'diOn', new pronun: 'd iy1 OO2 n'
# change 'diphthOng', new pronun: 'd ih1 p th OO0 ng'
# change 'discOgraphy', new pronun: 'd ih0 s k OO1 g r ax f iy0'
# change 'dishOnestly', new pronun: 'd ih0 s OO1 n ih0 s t l iy0'
# change 'dishOng', new pronun: 'd ih1 s OO0 ng'
# change 'dOff', new pronun: 'd OO1 f'
# change 'dOg', new pronun: 'd OO1 g'
# change 'dOgbane', new pronun: 'd OO1 g b ey2 n'
# change 'dOgfights', new pronun: 'd OO1 g f ay2 t s'
# change 'dOgfish', new pronun: 'd OO1 g f ih2 sh'
# change 'dOgged', new pronun: 'd OO1 g d'
# change 'dOgged', new pronun: 'd OO1 g ih0 d'
# change 'dOggie', new pronun: 'd OO1 g iy0'
# change 'dOgging', new pronun: 'd OO1 g ih0 ng'
# change 'dOggOne', new pronun: 'd OO1 g OO0 n'
# change 'dOggy', new pronun: 'd OO1 g iy0'
# change 'dOghOuse', new pronun: 'd OO1 g hh aw2 s'
# change 'dOghOuses', new pronun: 'd OO1 g hh aw2 s ih0 z'
# change 'dOgmatic', new pronun: 'd OO0 g m ae1 t ih0 k'
# change 'dOgmatically', new pronun: 'd OO0 g m ae1 t ih0 k l iy0'
# change 'dOgmatism', new pronun: 'd OO1 g m ax t ih2 z ax m'
# change 'dOgwOOd', new pronun: 'd OO1 g w uh2 d'
# change 'dOirOn', new pronun: 'd oy0 r OO1 n'
# change 'dOmbrOwski', new pronun: 'd ax m b r OO1 f s k iy0'
# change 'dOner', new pronun: 'd OO1 n axr'
# change 'dOng', new pronun: 'd OO1 ng'
# change 'dOngen', new pronun: 'd OO1 ng g ax n'
# change 'dOnkey', new pronun: 'd OO1 ng k iy0'
# change 'dOriOn', new pronun: 'd ao0 r iy0 OO1 n'
# change 'dOrnin', new pronun: 'd OO1 n ih0 n'
# change 'dOsch', new pronun: 'd OO1 sh'
# change 'dOskOcil', new pronun: 'd OO1 s k ax s ih0 l'
# change 'dOss', new pronun: 'd OO1 s'
# change 'dOssier', new pronun: 'd OO2 s y ey1'
# change 'dOstOevski', new pronun: 'd OO2 s t ow1 v s k iy0'
# change 'dOstOevsky', new pronun: 'd OO2 s t ow1 v s k iy0'
# change 'dOstOevsky', new pronun: 'd OO0 s t oy0 eh1 v s k iy0'
# change 'dOstOevsky', new pronun: 'd OO0 s t oy0 eh1 f s k iy0'
# change 'dOth', new pronun: 'd OO1 th'
# change 'drOpOff', new pronun: 'd r aa1 p OO2 f'
# change 'drOss', new pronun: 'd r OO1 s'
# change 'drOzdOwski', new pronun: 'd r ax z d OO1 f s k iy0'
# change 'dubOff', new pronun: 'd ah1 b OO2 f'
# change 'dulOng', new pronun: 'd uw1 l OO0 ng'
# changed 55 entries in D.yaml
# change 'eckhOff', new pronun: 'eh1 k hh OO2 f'
# change 'egelhOff', new pronun: 'eh1 g ih0 l hh OO0 f'
# change 'eggnOg', new pronun: 'eh1 g n OO2 g'
# change 'eickhOff', new pronun: 'ay1 k hh OO2 f'
# change 'electrOn', new pronun: 'ih0 l eh1 k t r OO0 n'
# change 'electrOnic', new pronun: 'ih0 l eh2 k t r OO1 n ih0 k'
# change 'electrOnically', new pronun: 'ih0 l eh2 k t r OO1 n ih0 k ax l iy0'
# change 'electrOnically', new pronun: 'ih0 l eh2 k t r OO1 n ih0 k l iy0'
# change 'eleemOsynary', new pronun: 'eh2 l ax m OO1 s ax n eh2 r iy0'
# change 'elOngate', new pronun: 'ih0 l OO1 ng g ey0 t'
# change 'elOngated', new pronun: 'ih0 l OO1 ng g ey0 t ih0 d'
# change 'elOngatiOn', new pronun: 'iy2 l OO0 ng g ey1 sh ax n'
# change 'embOss', new pronun: 'ih0 m b OO1 s'
# change 'encarnaciOn', new pronun: 'ih0 ng k aa2 r n ae0 s iy0 OO1 n'
# change 'endOscOpy', new pronun: 'eh2 n d OO1 s k aa0 p iy0'
# change 'enterOcOccus', new pronun: 'eh2 n t axr ax k OO1 k ax s'
# change 'eOff', new pronun: 'ey1 OO0 f'
# change 'eOn', new pronun: 'iy1 OO0 n'
# change 'eOs', new pronun: 'iy1 OO0 s'
# change 'eOsinOphilia', new pronun: 'iy2 OO0 s ih2 n ax f ih1 l iy0 ax'
# change 'eOsinOphilic', new pronun: 'iy2 OO0 s ih2 n ax f ih1 l ih0 k'
# change 'epilOgue', new pronun: 'eh2 p ih0 l OO1 g'
# change 'epOnymOus', new pronun: 'ih0 p OO1 n ih0 m ax s'
# change 'eriOn', new pronun: 'ih0 r iy0 OO1 n'
# change 'evanOff', new pronun: 'eh1 v ax n OO2 f'
# change 'exOn', new pronun: 'eh2 k s OO1 n'
# changed 25 entries in E.yaml
# change 'falkOwski', new pronun: 'f ax l k OO1 f s k iy0'
# change 'fallOff', new pronun: 'f ao1 l OO2 f'
# change 'fearOn', new pronun: 'f ih1 r OO0 n'
# change 'firefOx', new pronun: 'f ay1 axr f OO2 k s'
# change 'flintOff', new pronun: 'f l ih1 n t OO0 f'
# change 'flOssie', new pronun: 'f l OO1 s iy0'
# change 'fOg', new pronun: 'f OO1 g'
# change 'fOgarty', new pronun: 'f OO1 g aa2 r t iy0'
# change 'fOndle', new pronun: 'f OO1 n d ax l'
# change 'fOndled', new pronun: 'f OO1 n d ax l d'
# change 'fOng', new pronun: 'f OO1 ng'
# change 'fOntaine', new pronun: 'f OO0 n t ey1 n'
# change 'fOntana', new pronun: 'f OO0 n t ae1 n ax'
# change 'fOregOne', new pronun: 'f OO1 r g OO1 n'
# change 'frankOwski', new pronun: 'f r ax ng k OO1 f s k iy0'
# change 'frOhnmayer', new pronun: 'f r OO1 n m ay2 axr'
# change 'frOsch', new pronun: 'f r OO1 sh'
# change 'frOst', new pronun: 'f r OO1 s t'
# change 'frOstbite', new pronun: 'f r OO1 s t b ay2 t'
# change 'frOstbitten', new pronun: 'f r OO1 s t b ih2 t ax n'
# change 'frOsted', new pronun: 'f r OO1 s t ih0 d'
# change 'frOsty', new pronun: 'f r OO1 s t iy0'
# change 'frOth', new pronun: 'f r OO1 th'
# change 'frOthingham', new pronun: 'f r OO1 th ih0 ng hh ae2 m'
# change 'frOthy', new pronun: 'f r OO1 th iy0'
# change 'furlOng', new pronun: 'f er1 l OO2 ng'
# changed 26 entries in F.yaml
# change 'gabaldOn', new pronun: 'g aa0 b aa0 l d OO1 n'
# change 'gambOn', new pronun: 'g ae1 m b OO0 n'
# change 'gamecOck', new pronun: 'g ey1 m k OO2 k'
# change 'ganglOff', new pronun: 'g ae1 ng g l OO0 f'
# change 'ganOng', new pronun: 'g ae1 n OO0 ng'
# change 'garOn', new pronun: 'g eh0 r OO1 n'
# change 'gerlOff', new pronun: 'g er1 l OO0 f'
# change 'gerOnimO', new pronun: 'jh ax r OO1 n ih0 m ow0'
# change 'girOnde', new pronun: 'jh axr OO1 n d'
# change 'glOgOwski', new pronun: 'g l ax g OO1 f s k iy0'
# change 'glOss', new pronun: 'g l OO1 s'
# change 'glOssary', new pronun: 'g l OO1 s axr iy0'
# change 'glOsser', new pronun: 'g l OO1 s axr'
# change 'glOsses', new pronun: 'g l OO1 s ih0 z'
# change 'glOssier', new pronun: 'g l OO1 s iy0 axr'
# change 'glOssy', new pronun: 'g l OO1 s iy0'
# change 'glOucester', new pronun: 'g l OO1 s t axr'
# change 'gOff', new pronun: 'g OO1 f'
# change 'gOldilOcks', new pronun: 'g ow1 l d iy0 l OO2 k s'
# change 'gOldwasser', new pronun: 'g ow1 l d w OO0 s axr'
# change 'gOne', new pronun: 'g OO1 n'
# change 'gOng', new pronun: 'g OO1 ng'
# change 'gOsch', new pronun: 'g OO1 sh'
# change 'gOspel', new pronun: 'g OO1 s p ax l'
# change 'gOss', new pronun: 'g OO1 s'
# change 'gOssage', new pronun: 'g OO1 s ih0 jh'
# change 'gOssen', new pronun: 'g OO1 s ax n'
# change 'gOsser', new pronun: 'g OO1 s axr'
# change 'gOssman', new pronun: 'g OO1 s m ax n'
# change 'gOugh', new pronun: 'g OO1 f'
# change 'grabOwski', new pronun: 'g r ax b OO1 f s k iy0'
# change 'granOff', new pronun: 'g r ae1 n OO0 f'
# change 'grOchOwski', new pronun: 'g r ax ch OO1 f s k iy0'
# change 'grOff', new pronun: 'g r OO1 f'
# change 'grOsch', new pronun: 'g r OO1 sh'
# change 'grOssmann', new pronun: 'g r OO1 s m ax n'
# change 'guangdOng', new pronun: 'g w ae1 ng d OO1 ng'
# change 'guangdOng', new pronun: 'g w aa1 ng d OO1 ng'
# change 'guiOn', new pronun: 'g w iy0 OO1 n'
# change 'gundOg', new pronun: 'g ah1 n d OO2 g'
# change 'gutOwski', new pronun: 'g ax t OO1 f s k iy0'
# changed 40 entries in G.yaml
# change 'hackathOn', new pronun: 'hh ae1 k ax th OO2 n'
# change 'hadrOn', new pronun: 'hh ae1 d r OO0 n'
# change 'hargadOn', new pronun: 'hh aa0 r g aa0 d OO1 n'
# change 'haylOft', new pronun: 'hh ey1 l OO2 f t'
# change 'hbOx', new pronun: 'ey1 ch b OO1 k s'
# change 'headlOng', new pronun: 'hh eh1 d l OO2 ng'
# change 'headstrOng', new pronun: 'hh eh1 d s t r OO2 ng'
# change 'hebrOn', new pronun: 'hh eh1 b r OO2 n'
# change 'hentOff', new pronun: 'hh eh1 n t OO0 f'
# change 'herlOng', new pronun: 'hh er1 l OO0 ng'
# change 'hippOcrates', new pronun: 'hh ih0 p OO1 k r ih0 t iy0 z'
# change 'hmOng', new pronun: 'm OO1 ng'
# change 'hmOng', new pronun: 'hh m OO1 ng'
# change 'hmOng', new pronun: 'hh ax m OO1 ng'
# change 'hOff', new pronun: 'hh OO1 f'
# change 'hOffa', new pronun: 'hh OO1 f ax'
# change 'hOffert', new pronun: 'hh OO1 f axr t'
# change 'hOffman', new pronun: 'hh OO1 f m ax n'
# change 'hOffmann', new pronun: 'hh OO1 f m ax n'
# change 'hOffmeister', new pronun: 'hh OO1 f m ay2 s t axr'
# change 'hOffmeyer', new pronun: 'hh OO1 f m ay0 axr'
# change 'hOffner', new pronun: 'hh OO1 f n axr'
# change 'hOgging', new pronun: 'hh OO1 g ih0 ng'
# change 'hOglund', new pronun: 'hh OO1 g l ax n d'
# change 'hOgwOOd', new pronun: 'hh OO1 g w uh2 d'
# change 'hOk', new pronun: 'hh OO1 k'
# change 'hOlOcaust', new pronun: 'hh ao1 l ow0 k OO2 s t'
# change 'hOnchO', new pronun: 'hh OO1 n ch ow0'
# change 'hOnda', new pronun: 'hh OO1 n d ax'
# change 'hOng', new pronun: 'hh OO1 ng'
# change 'hOngkOng', new pronun: 'hh OO1 ng k OO0 ng'
# change 'hOngwei', new pronun: 'hh OO1 ng w ey1'
# change 'hOnk', new pronun: 'hh OO1 ng k'
# change 'hOnky', new pronun: 'hh OO1 ng k iy0'
# change 'hOnOra', new pronun: 'OO0 n ao1 r ax'
# change 'hOpalOng', new pronun: 'hh aa1 p ax l OO0 ng'
# change 'hOrizOntal', new pronun: 'hh ao2 r ih0 z OO1 n t ax l'
# change 'hOrwath', new pronun: 'hh ao1 r w OO0 th'
# change 'hOsch', new pronun: 'hh OO1 sh'
# change 'hOskyns', new pronun: 'hh OO1 s k ih0 n z'
# change 'hOsni', new pronun: 'hh OO1 s n iy0'
# change 'hOspitable', new pronun: 'hh OO1 s p ih1 t ax b ax l'
# change 'hOspital', new pronun: 'hh OO1 s p ih2 t ax l'
# change 'hOspitality', new pronun: 'hh OO2 s p ax t ae1 l ax t iy0'
# change 'hOspitalizatiOn', new pronun: 'hh OO2 s p ih0 t ax l ax z ey1 sh ax n'
# change 'hOspitalize', new pronun: 'hh OO1 s p ih2 t ax l ay2 z'
# change 'hOspitalized', new pronun: 'hh OO1 s p ih0 t ax l ay2 z d'
# change 'hOspitals', new pronun: 'hh OO1 s p ih0 t ax l z'
# change 'hOssein', new pronun: 'hh OO1 s ey2 n'
# change 'hOstage', new pronun: 'hh OO1 s t ih0 jh'
# change 'hOstages', new pronun: 'hh OO1 s t ih0 jh ih0 z'
# change 'hOtdOg', new pronun: 'hh aa1 t d OO2 g'
# change 'hOurlOng', new pronun: 'aw1 axr l OO2 ng'
# change 'humOngOus', new pronun: 'hh y uw0 m OO1 ng g ax s'
# change 'hydrOx', new pronun: 'hh ay1 d r OO2 k s'
# change 'hydrOxy', new pronun: 'hh ay2 d r OO1 k s iy0'
# changed 54 entries in H.yaml
# change 'ideOlOgues', new pronun: 'ay1 d iy0 ax l OO0 g z'
# change 'imhOff', new pronun: 'ih1 m hh OO2 f'
# change 'immunOperOxidase', new pronun: 'ih2 m y uw0 n ow0 p axr OO1 k s ih0 d ey2 z'
# change 'impetuOsity', new pronun: 'ih0 m p eh2 ch uw0 OO1 s ih0 t iy0'
# change 'impOssibility', new pronun: 'ih0 m p OO2 s ih0 b ih1 l ih0 t iy0'
# change 'impOster', new pronun: 'ih0 m p OO1 s t axr'
# change 'impOstOr', new pronun: 'ih0 m p OO1 s t axr'
# change 'impOsture', new pronun: 'ih0 m p OO1 s ch axr'
# change 'incheOn', new pronun: 'ih1 n ch OO0 n'
# change 'inchOn', new pronun: 'ih1 n ch OO0 n'
# change 'incOgnitO', new pronun: 'ih0 ng k OO0 g n iy1 t ow0'
# change 'incOngruity', new pronun: 'ih2 ng k OO0 ng r uw1 ih0 t iy0'
# change 'incOngruOus', new pronun: 'ih0 ng k OO1 ng r uw0 ax s'
# change 'innOculated', new pronun: 'ih0 n OO1 k y ax l ey2 t ih0 d'
# change 'innOculating', new pronun: 'ih0 n OO1 k y ax l ey2 t ih0 ng'
# change 'interOffice', new pronun: 'ih2 n t axr OO1 f ih0 s'
# change 'iOnOsphere', new pronun: 'ay2 aa1 n OO0 s f ih2 r'
# change 'iOnOspheric', new pronun: 'ay2 aa2 n OO0 s f eh1 r ih0 k'
# change 'iOsif', new pronun: 'y OO1 s ih0 f'
# change 'isikOff', new pronun: 'ih1 z ax k OO0 f'
# change 'isOsceles', new pronun: 'ay0 s OO1 s ax l iy2 z'
# change 'ivanOff', new pronun: 'ih1 v ax n OO0 f'
# changed 22 entries in I.yaml
# change 'jackOwski', new pronun: 'y ax s k OO1 f s k iy0'
# change 'jakubOwski', new pronun: 'y ax k ax b OO1 f s k iy0'
# change 'janikOwski', new pronun: 'y ax n ih0 k OO1 f s k iy0'
# change 'jankOwski', new pronun: 'y ax ng k OO1 f s k iy0'
# change 'janOff', new pronun: 'jh ae1 n OO0 f'
# change 'janOfsky', new pronun: 'jh ax n OO1 f s k iy0'
# change 'janOwski', new pronun: 'y ax n OO1 f s k iy0'
# change 'jarmOn', new pronun: 'y aa0 r m OO1 n'
# change 'jOcelyn', new pronun: 'jh OO1 s l ih2 n'
# change 'jOcelyne', new pronun: 'jh OO1 s l ih2 n'
# change 'jOcOse', new pronun: 'jh OO2 k ow1 z'
# change 'jOffrey', new pronun: 'jh OO1 f r iy0'
# change 'jOg', new pronun: 'jh OO1 g'
# change 'jOgged', new pronun: 'jh OO1 g d'
# change 'jOgger', new pronun: 'jh OO1 g axr'
# change 'jOgging', new pronun: 'jh OO1 g ih0 ng'
# change 'jOnbenet', new pronun: 'jh OO1 n b ax n ey1'
# change 'jOnbenet's', new pronun: 'jh OO1 n b ax n ey1 ' s'
# change 'jOng', new pronun: 'jh OO1 ng'
# change 'jOshua', new pronun: 'jh OO1 sh uw0 ax'
# change 'jOshua's', new pronun: 'jh OO1 sh uw2 ax ' z'
# change 'jOske's', new pronun: 'jh OO1 s k iy0 ' z'
# change 'jOslyn', new pronun: 'jh OO1 s l ih0 n'
# change 'jOss', new pronun: 'jh OO1 s'
# change 'jOstens', new pronun: 'jh OO1 s t ax n z'
# change 'jumbOtrOn', new pronun: 'jh ah1 m b ow0 t r OO0 n'
# changed 26 entries in J.yaml
# change 'kaczOrOwski', new pronun: 'k ax ch axr OO1 f s k iy0'
# change 'kafelnikOv', new pronun: 'k ax f eh1 l n ih0 k OO2 f'
# change 'kalinOwski', new pronun: 'k ax l ih0 n OO1 f s k iy0'
# change 'karwOwski', new pronun: 'k axr v OO1 f s k iy0'
# change 'kellOgg', new pronun: 'k eh1 l OO0 g'
# change 'kerkhOff', new pronun: 'k er1 k hh OO0 f'
# change 'khOsla', new pronun: 'k OO1 s l ax'
# change 'kickOff', new pronun: 'k ih1 k OO2 f'
# change 'kiOsk', new pronun: 'k iy1 OO2 s k'
# change 'kirchhOff', new pronun: 'k er1 k hh OO0 f'
# change 'kirchOff', new pronun: 'k er1 k hh OO0 f'
# change 'kirwan', new pronun: 'k er1 w OO0 n'
# change 'kjOs', new pronun: 'k y OO1 s'
# change 'klinghOffer', new pronun: 'k l ih1 ng hh OO2 f axr'
# change 'klingOn', new pronun: 'k l ih1 ng g OO2 n'
# change 'klOs', new pronun: 'k l OO1 s'
# change 'klOss', new pronun: 'k l OO1 s'
# change 'klOster', new pronun: 'k l OO1 s t axr'
# change 'knOckOff', new pronun: 'n aa1 k OO2 f'
# change 'kOester', new pronun: 'k OO1 s t axr'
# change 'kOff', new pronun: 'k OO1 f'
# change 'kOffman', new pronun: 'k OO1 f m ax n'
# change 'kOkOschka', new pronun: 'k ax k OO1 sh k ax'
# change 'kOlakOwski', new pronun: 'k ax l ax k OO1 f s k iy0'
# change 'kOmOrOwski', new pronun: 'k ax m axr OO1 f s k iy0'
# change 'kOng', new pronun: 'k OO1 ng'
# change 'kOngsberg', new pronun: 'k OO1 ng z b axr g'
# change 'kOngsberg', new pronun: 'k OO1 ng g z b axr g'
# change 'kOprOwski', new pronun: 'k ax p r OO1 f s k iy0'
# change 'kOrns', new pronun: 'k OO1 n z'
# change 'kOsch', new pronun: 'k OO1 sh'
# change 'kOslOwski', new pronun: 'k ax s l OO1 f s k iy0'
# change 'kOss', new pronun: 'k OO1 s'
# change 'kOzlOff', new pronun: 'k aa1 z l OO0 f'
# change 'kOzlOwski', new pronun: 'k ax z l OO1 f s k iy0'
# change 'krakOwski', new pronun: 'k r ax k OO1 f s k iy0'
# change 'krasnOff', new pronun: 'k r ae1 s n OO0 f'
# change 'kratOs', new pronun: 'k r ae1 t OO2 s'
# change 'kristOfer', new pronun: 'k r ih1 s t OO0 f axr'
# change 'kristOff', new pronun: 'k r ih1 s t OO0 f'
# change 'kristOffersOn', new pronun: 'k r ih2 s t OO1 f axr s ax n'
# change 'krOss', new pronun: 'k r OO1 s'
# change 'krzysztOf', new pronun: 'k r iy1 s t OO0 f'
# change 'krzysztOf', new pronun: 'k r iy1 sh t OO0 f'
# change 'kulikOwski', new pronun: 'k y uw0 l ih0 k OO1 f s k iy0'
# change 'kurOwski', new pronun: 'k axr OO1 f s k iy0'
# change 'kwiatkOwski', new pronun: 'k w iy0 ax t k OO1 f s k iy0'
# change 'kwOng', new pronun: 'k w OO1 ng'
# change 'kyOng', new pronun: 'k y OO1 ng'
# change 'kyOngsang', new pronun: 'k y OO1 ng s ae0 ng'
# change 'kyOung', new pronun: 'k y OO1 ng'
# changed 49 entries in K.yaml
# change 'lacOste', new pronun: 'l aa0 k OO1 s t'
# change 'lacrOsse', new pronun: 'l ax k r OO1 s'
# change 'lafOnd', new pronun: 'l ae0 f OO1 n d'
# change 'lafOnt', new pronun: 'l ae0 f OO1 n t'
# change 'lafOntaine', new pronun: 'l ae2 f OO0 n t ey1 n'
# change 'lafOuntain', new pronun: 'l ae0 f OO1 n t ey0 n'
# change 'lagOs', new pronun: 'l ey1 g OO0 s'
# change 'lamOn', new pronun: 'l aa0 m OO1 n'
# change 'lamOthe', new pronun: 'l ae0 m OO1 th'
# change 'langhOff', new pronun: 'l ae1 ng hh OO0 f'
# change 'lapdOg', new pronun: 'l ae1 p d OO2 g'
# change 'laryngOscOpy', new pronun: 'l eh2 r ih0 n jh OO1 s k ow0 p iy0'
# change 'laskOwski', new pronun: 'l ax s k OO1 f s k iy0'
# change 'layOff', new pronun: 'l ey1 OO2 f'
# change 'lazarOff', new pronun: 'l ae1 z axr OO0 f'
# change 'leadOff', new pronun: 'l iy1 d OO2 f'
# change 'leapfrOg', new pronun: 'l iy1 p f r OO2 g'
# change 'leapfrOgged', new pronun: 'l iy1 p f r OO2 g d'
# change 'leapfrOgging', new pronun: 'l iy1 p f r OO2 g ih0 ng'
# change 'leOnidas', new pronun: 'l iy0 OO2 n ay1 d ax s'
# change 'lewandOwski', new pronun: 'l uw0 ax n d OO1 f s k iy0'
# change 'lifelOng', new pronun: 'l ay1 f l OO1 ng'
# change 'liftOff', new pronun: 'l ih1 f t OO2 f'
# change 'lindrOth', new pronun: 'l ih1 n d r OO2 th'
# change 'lisOwski', new pronun: 'l ih0 s OO1 f s k iy0'
# change 'litwack', new pronun: 'l ih1 t w OO0 k'
# change 'lOft', new pronun: 'l OO1 f t'
# change 'lOfthOuse', new pronun: 'l OO1 f t hh aw2 s'
# change 'lOftier', new pronun: 'l OO1 f t iy0 axr'
# change 'lOftus', new pronun: 'l OO1 f t ax s'
# change 'lOfty', new pronun: 'l OO1 f t iy0'
# change 'lOg', new pronun: 'l OO1 g'
# change 'lOgbOOk', new pronun: 'l OO1 g b uh2 k'
# change 'lOgged', new pronun: 'l OO1 g d'
# change 'lOgging', new pronun: 'l OO1 g ih0 ng'
# change 'lOgin', new pronun: 'l OO1 g ih2 n'
# change 'lOgOut', new pronun: 'l OO1 g aw2 t'
# change 'lOinclOth', new pronun: 'l oy1 ng k l OO2 th'
# change 'lOng', new pronun: 'l OO1 ng'
# change 'lOngacre', new pronun: 'l OO1 ng ey2 k axr'
# change 'lOngbOw', new pronun: 'l OO1 ng b ow0'
# change 'lOngden', new pronun: 'l OO1 ng d eh2 n'
# change 'lOnger', new pronun: 'l OO1 ng g axr'
# change 'lOngest', new pronun: 'l OO1 ng g ih0 s t'
# change 'lOngevity', new pronun: 'l OO0 n jh eh1 v ax t iy0'
# change 'lOngfellOw', new pronun: 'l OO1 ng f eh2 l ow0'
# change 'lOngfield', new pronun: 'l OO1 ng f iy2 l d'
# change 'lOnghair', new pronun: 'l OO1 ng hh eh2 r'
# change 'lOnghand', new pronun: 'l OO1 ng hh ae2 n d'
# change 'lOnghi', new pronun: 'l OO1 ng g iy0'
# change 'lOnghOrn', new pronun: 'l OO1 ng hh ao2 r n'
# change 'lOnghOuse', new pronun: 'l OO1 ng hh aw2 s'
# change 'lOngingly', new pronun: 'l OO1 ng ih0 ng l iy0'
# change 'lOngish', new pronun: 'l OO1 ng ih0 sh'
# change 'lOngleaf', new pronun: 'l OO1 ng l iy2 f'
# change 'lOngleg', new pronun: 'l OO1 ng l eh2 g'
# change 'lOngman', new pronun: 'l OO1 ng m ax n'
# change 'lOngmOnt', new pronun: 'l OO1 ng m aa2 n t'
# change 'lOngnecker', new pronun: 'l OO1 ng n eh2 k axr'
# change 'lOngO', new pronun: 'l OO1 ng g ow0'
# change 'lOngshOre', new pronun: 'l OO1 ng sh ao2 r'
# change 'lOngshOremen', new pronun: 'l OO1 ng sh OO1 r m ih0 n'
# change 'lOngshOt', new pronun: 'l OO1 ng sh aa2 t'
# change 'lOngspur', new pronun: 'l OO1 ng s p er2'
# change 'lOngstaff', new pronun: 'l OO1 ng s t ae2 f'
# change 'lOngstanding', new pronun: 'l OO1 ng s t ae2 n d ih0 ng'
# change 'lOngstreet', new pronun: 'l OO1 ng s t r iy2 t'
# change 'lOngterm', new pronun: 'l OO1 ng t er2 m'
# change 'lOngtime', new pronun: 'l OO1 ng t ay2 m'
# change 'lOngtin', new pronun: 'l OO1 ng t ih0 n'
# change 'lOngtOn', new pronun: 'l OO1 ng t ax n'
# change 'lOnguet', new pronun: 'l OO1 ng w eh2 t'
# change 'lOngview', new pronun: 'l OO1 ng v y uw2'
# change 'lOngwell', new pronun: 'l OO1 ng w eh2 l'
# change 'lOngwOOd', new pronun: 'l OO1 ng w uh2 d'
# change 'lOngwOrth', new pronun: 'l OO1 ng w er2 th'
# change 'lOnnie', new pronun: 'l OO1 n iy0'
# change 'lOnny', new pronun: 'l OO1 n iy0'
# change 'lOs', new pronun: 'l OO1 s'
# change 'lOsch', new pronun: 'l OO1 sh'
# change 'lOsey', new pronun: 'l OO1 s iy0'
# change 'lOss', new pronun: 'l OO1 s'
# change 'lOsses', new pronun: 'l OO1 s ih0 z'
# change 'lOst', new pronun: 'l OO1 s t'
# change 'lOughlin', new pronun: 'l OO1 f l ih0 n'
# change 'luOng', new pronun: 'l uw0 OO1 ng'
# changed 86 entries in L.yaml
# change 'macintOsh', new pronun: 'm ae1 k ax n t OO2 sh'
# change 'macintOshes', new pronun: 'm ae1 k ax n t OO2 sh ih0 z'
# change 'madelOn', new pronun: 'm aa0 d ey0 l OO1 n'
# change 'madOff', new pronun: 'm ae1 d OO2 f'
# change 'mahlOn', new pronun: 'm ey1 l OO2 n'
# change 'makOwski', new pronun: 'm ax k OO1 f s k iy0'
# change 'malathiOn', new pronun: 'm ax l ae1 th iy0 OO0 n'
# change 'malinOwski', new pronun: 'm ax l ih0 n OO1 f s k iy0'
# change 'malkOwski', new pronun: 'm ax l k OO1 f s k iy0'
# change 'maniOn', new pronun: 'm aa0 n y OO1 n'
# change 'mankOwski', new pronun: 'm ax ng k OO1 f s k iy0'
# change 'manOff', new pronun: 'm ae1 n OO0 f'
# change 'manOn', new pronun: 'm aa0 n OO1 n'
# change 'marcinkOwski', new pronun: 'm axr ch ih0 ng k OO1 f s k iy0'
# change 'markOff', new pronun: 'm aa1 r k OO2 f'
# change 'markOwski', new pronun: 'm axr k OO1 f s k iy0'
# change 'marOc', new pronun: 'm aa2 r OO1 k'
# change 'marOn', new pronun: 'm aa0 r OO1 n'
# change 'maslOwski', new pronun: 'm ax s l OO1 f s k iy0'
# change 'mastOdOn', new pronun: 'm ae1 s t ax d OO2 n'
# change 'matalOn', new pronun: 'm aa0 t aa0 l OO1 n'
# change 'mayOn', new pronun: 'm ey0 OO1 n'
# change 'mazOn', new pronun: 'm aa0 z OO1 n'
# change 'mcclOskey', new pronun: 'm ax k l OO1 s k iy0'
# change 'mcclOsky', new pronun: 'm ax k l OO1 s k iy0'
# change 'mccOnaughey', new pronun: 'm ax k OO1 n ax g ey0'
# change 'mccOnaughy', new pronun: 'm ax k OO1 n ax g iy0'
# change 'mccOnnaughey', new pronun: 'm ax k OO1 n ax g ey0'
# change 'mcintOsh', new pronun: 'm ae1 k ax n t OO2 sh'
# change 'meckstrOth', new pronun: 'm eh1 k s t r OO0 th'
# change 'medOc', new pronun: 'm eh0 d OO1 k'
# change 'medOff', new pronun: 'm eh1 d OO0 f'
# change 'megatrOn', new pronun: 'm eh1 g ax t r OO2 n'
# change 'melbOurne', new pronun: 'm eh1 l b OO0 n'
# change 'menOn', new pronun: 'm ey0 n OO1 n'
# change 'meritOcracy', new pronun: 'm eh0 r ih0 t OO1 k r ax s iy0'
# change 'metagOgued', new pronun: 'm eh1 t ax g OO2 g d'
# change 'meyerhOff', new pronun: 'm ay1 axr hh OO0 f'
# change 'miccOsukee', new pronun: 'm ih2 k OO0 s uw1 k iy0'
# change 'michalOwski', new pronun: 'm ih2 ch ax l OO1 f s k iy0'
# change 'micrOnic', new pronun: 'm ay2 k r OO1 n ih2 k'
# change 'micrOsOft', new pronun: 'm ay1 k r ow2 s OO1 f t'
# change 'mindbOggling', new pronun: 'm ay1 n d b OO2 g l ih0 ng'
# change 'minkOff', new pronun: 'm ih1 ng k OO2 f'
# change 'minnetOnka', new pronun: 'm ih2 n ih0 t OO1 ng k ax'
# change 'minOgue', new pronun: 'm iy1 n OO0 g'
# change 'minskOff', new pronun: 'm ih1 n s k OO0 f'
# change 'mirOn', new pronun: 'm ih0 r OO1 n'
# change 'mishawaka', new pronun: 'm ih2 sh ax w OO1 k ax'
# change 'mitOfsky', new pronun: 'm ih0 t OO1 f s k iy0'
# change 'mOhawk', new pronun: 'm ow1 hh OO2 k'
# change 'mOlOny', new pronun: 'm ax l OO1 n iy0'
# change 'mOndragOn', new pronun: 'm ow0 n d r aa0 g OO1 n'
# change 'mOng', new pronun: 'm OO1 ng'
# change 'mOnOgamOus', new pronun: 'm ax n OO1 g ax m ax s'
# change 'mOnOgamy', new pronun: 'm ax n OO1 g ax m iy0'
# change 'mOnOlOgue', new pronun: 'm aa1 n ow0 l OO2 g'
# change 'mOnOngahela', new pronun: 'm ax n OO2 ng g ax hh ey1 l ax'
# change 'mOntanO', new pronun: 'm OO2 n t aa1 n ow0'
# change 'mOntegO', new pronun: 'm OO2 n t iy1 g ow0'
# change 'mOnthlOng', new pronun: 'm ah1 n th l OO2 ng'
# change 'mOntresOr', new pronun: 'm OO0 n t r eh1 s axr'
# change 'mOnty', new pronun: 'm OO1 n t iy0'
# change 'mOnzOn', new pronun: 'm ow0 n z OO1 n'
# change 'mOOrcrOft', new pronun: 'm uh1 r k r OO2 f t'
# change 'mOrgenrOth', new pronun: 'm ao1 r g ih0 n r OO0 th'
# change 'mOs', new pronun: 'm OO1 s'
# change 'mOsby', new pronun: 'm OO1 s b iy0'
# change 'mOscOw', new pronun: 'm OO1 s k ow0'
# change 'mOsh', new pronun: 'm OO1 sh'
# change 'mOsk', new pronun: 'm OO1 s k'
# change 'mOskatel's', new pronun: 'm OO2 s k ax t eh1 l ' z'
# change 'mOskOwitz', new pronun: 'm OO1 s k ax w ih0 t s'
# change 'mOsque', new pronun: 'm OO1 s k'
# change 'mOss', new pronun: 'm OO1 s'
# change 'mOssberg', new pronun: 'm OO1 s b axr g'
# change 'mOsser', new pronun: 'm OO1 s axr'
# change 'mOsses', new pronun: 'm OO1 s ih0 z'
# change 'mOssman', new pronun: 'm OO1 s m ax n'
# change 'mOssy', new pronun: 'm OO1 s iy0'
# change 'mOth', new pronun: 'm OO1 th'
# change 'mOthball', new pronun: 'm OO1 th b ao2 l'
# change 'mOthballing', new pronun: 'm OO1 th b OO1 l ih0 ng'
# change 'mOutOn', new pronun: 'm uw1 t OO0 n'
# change 'mOuzOn', new pronun: 'm uw0 z OO1 n'
# change 'mycrOft', new pronun: 'm ay1 k r OO0 f t'
# changed 86 entries in M.yaml
# change 'natchitOches', new pronun: 'n ae0 k ax t OO1 sh'
# change 'nemerOff', new pronun: 'n eh1 m axr OO0 f'
# change 'neuenschwander', new pronun: 'n uw1 ax n sh w OO0 n d axr'
# change 'neuhOff', new pronun: 'n uw1 hh OO2 f'
# change 'niehOff', new pronun: 'n iy1 hh OO0 f'
# change 'niswOnger', new pronun: 'n ih1 s w OO0 ng axr'
# change 'nOfziger', new pronun: 'n OO1 f z ih0 g axr'
# change 'nOrcrOss', new pronun: 'n ao1 r k r OO0 s'
# change 'nOss', new pronun: 'n OO1 s'
# change 'nOstalgia', new pronun: 'n OO0 s t ae1 l jh ax'
# change 'nOstalgic', new pronun: 'n OO0 s t ae1 l jh ih0 k'
# change 'nOstra', new pronun: 'n OO1 s t r ax'
# change 'nOstradamus', new pronun: 'n OO2 s t r ax d ae1 m ax s'
# change 'nOvOsti', new pronun: 'n ow0 v OO1 s t iy0'
# change 'nOwakOwski', new pronun: 'n aw0 ax k OO1 f s k iy0'
# changed 15 entries in N.yaml
# change 'OblOng', new pronun: 'aa1 b l OO0 ng'
# change 'Oct', new pronun: 'OO1 k t'
# change 'Ocular', new pronun: 'OO1 k y uw0 l axr'
# change 'Off', new pronun: 'OO1 f'
# change 'Offbeat', new pronun: 'OO1 f b iy1 t'
# change 'Offen', new pronun: 'OO1 f ax n'
# change 'Offer', new pronun: 'OO1 f axr'
# change 'Offerer', new pronun: 'OO1 f axr axr'
# change 'Offerman', new pronun: 'OO1 f axr m ax n'
# change 'Offermann', new pronun: 'OO1 f axr m ax n'
# change 'Offhand', new pronun: 'OO1 f hh ae1 n d'
# change 'Office', new pronun: 'OO1 f ih0 s'
# change 'OfficehOlder', new pronun: 'OO1 f ih0 s hh ow2 l d axr'
# change 'Officemax', new pronun: 'OO1 f ih0 s m ae2 k s'
# change 'Officer', new pronun: 'OO1 f ih0 s axr'
# change 'Offices', new pronun: 'OO1 f ih0 s ih0 z'
# change 'Offline', new pronun: 'OO1 f l ay2 n'
# change 'Offset', new pronun: 'OO0 f s eh1 t'
# change 'Offset', new pronun: 'OO1 f s eh2 t'
# change 'Offsetting', new pronun: 'OO0 f s eh1 t ih0 ng'
# change 'Offsetting', new pronun: 'OO1 f s eh2 t ih0 ng'
# change 'OffshOOt', new pronun: 'OO1 f sh uw2 t'
# change 'OffshOre', new pronun: 'OO1 f sh OO1 r'
# change 'OffshOred', new pronun: 'OO1 f sh OO1 r d'
# change 'Offspring', new pronun: 'OO1 f s p r ih2 ng'
# change 'Offstage', new pronun: 'OO1 f s t ey1 jh'
# change 'Oft', new pronun: 'OO1 f t'
# change 'Often', new pronun: 'OO1 f t ax n'
# change 'Oftener', new pronun: 'OO1 f t ax n axr'
# change 'Oftentimes', new pronun: 'OO1 f t ax n t ay2 m z'
# change 'OkalOOsa', new pronun: 'OO2 k ax l uw1 s ax'
# change 'OlOf', new pronun: 'ow1 l OO0 f'
# change 'On', new pronun: 'OO1 n'
# change 'OncOming', new pronun: 'OO1 ng k ah2 m ih0 ng'
# change 'OndO', new pronun: 'OO1 n d ow0'
# change 'Ong', new pronun: 'OO1 ng'
# change 'OngOing', new pronun: 'OO1 ng g ow2 ih0 ng'
# change 'Online', new pronun: 'OO1 n l ay2 n'
# change 'OnlOOker', new pronun: 'OO1 n l uh2 k axr'
# change 'OnOfre', new pronun: 'ow0 n OO1 f r iy0'
# change 'Onrushing', new pronun: 'OO1 n r ah2 sh ih0 ng'
# change 'Onscreen', new pronun: 'OO2 n s k r iy1 n'
# change 'Onset', new pronun: 'OO1 n s eh2 t'
# change 'OnshOre', new pronun: 'OO1 n sh ao2 r'
# change 'Onsite', new pronun: 'OO1 n s ay1 t'
# change 'Onslaught', new pronun: 'OO1 n s l ao2 t'
# change 'OnslOw', new pronun: 'OO1 n s l ow0'
# change 'Onstage', new pronun: 'OO2 n s t ey1 jh'
# change 'OntO', new pronun: 'OO1 n t uw0'
# change 'Onward', new pronun: 'OO1 n w axr d'
# change 'OOlOng', new pronun: 'uw1 l OO0 ng'
# change 'OrlOff', new pronun: 'ao1 r l OO0 f'
# change 'OrlOwski', new pronun: 'ao0 r l OO1 f s k iy0'
# change 'OrthOgOnal', new pronun: 'ao0 r th OO1 g ax n ax l'
# change 'OrzechOwski', new pronun: 'ao0 r z ih0 hh OO1 f s k iy0'
# change 'Oscar', new pronun: 'OO1 s k axr'
# change 'OsceOla', new pronun: 'OO2 s k iy0 ow1 l ax'
# change 'OsceOla', new pronun: 'OO2 s iy0 ow1 l ax'
# change 'OscillOscOpe', new pronun: 'OO2 s ih1 l ax s k ow2 p'
# change 'Oshawa', new pronun: 'OO2 sh aa1 w ax'
# change 'OshkOsh', new pronun: 'OO1 sh k OO2 sh'
# change 'Oshman', new pronun: 'OO1 sh m ax n'
# change 'Oskar', new pronun: 'OO1 s k axr'
# change 'Osprey', new pronun: 'OO1 s p r iy0'
# change 'Oss', new pronun: 'OO1 s'
# change 'OstentatiOn', new pronun: 'OO2 s t eh0 n t ey1 sh ax n'
# change 'OsteOpOrOsis', new pronun: 'OO2 s t iy0 aa2 p axr ow1 s ih0 s'
# change 'Osterreichische', new pronun: 'OO1 s t axr r ay2 k ih0 sh iy0'
# change 'OsthOff', new pronun: 'aa1 s t hh OO0 f'
# change 'Ostracism', new pronun: 'OO1 s t r ax s ih2 z ax m'
# change 'Ostracize', new pronun: 'OO1 s t r ax s ay2 z'
# change 'Ostracized', new pronun: 'OO1 s t r ax s ay2 z d'
# change 'Ostrich', new pronun: 'OO1 s t r ih0 ch'
# change 'OstrOff', new pronun: 'OO1 s t r OO0 f'
# change 'OstrOwski', new pronun: 'ax s t r OO1 f s k iy0'
# change 'OwOssO', new pronun: 'ow0 OO1 s ow0'
# changed 75 entries in O.yaml
# change 'pabOn', new pronun: 'p aa0 b OO1 n'
# change 'paczkOwski', new pronun: 'p ax ch k OO1 f s k iy0'
# change 'papOn', new pronun: 'p ae1 p OO0 n'
# change 'pawlikOwski', new pronun: 'p aa0 v l ih0 k OO1 f s k iy0'
# change 'pawlOwski', new pronun: 'p aa0 v l OO1 f s k iy0'
# change 'payOff', new pronun: 'p ey1 OO2 f'
# change 'pentecOst', new pronun: 'p eh1 n t ax k OO2 s t'
# change 'pentecOstal', new pronun: 'p eh2 n t ax k OO1 s t ax l'
# change 'perkOwski', new pronun: 'p axr k OO1 f s k iy0'
# change 'perOn', new pronun: 'p axr OO1 n'
# change 'petrOff', new pronun: 'p eh1 t r OO0 f'
# change 'phuOng', new pronun: 'f uw0 OO1 ng'
# change 'piatkOwski', new pronun: 'p iy0 ax t k OO1 f s k iy0'
# change 'pierrOn', new pronun: 'p ih0 r OO1 n'
# change 'pilOn', new pronun: 'p iy0 l OO1 n'
# change 'pingpOng', new pronun: 'p ih1 ng p OO0 ng'
# change 'pinzOn', new pronun: 'p ih2 n z OO1 n'
# change 'piOtrOwski', new pronun: 'p iy0 ow0 t r OO1 f s k iy0'
# change 'pitOn', new pronun: 'p iy1 t OO2 n'
# change 'plainsOng', new pronun: 'p l ey1 n s OO2 ng'
# change 'plamOndOn', new pronun: 'p l aa0 m ow0 n d OO1 n'
# change 'playOff', new pronun: 'p l ey1 OO2 f'
# change 'pleOmOrphic', new pronun: 'p l iy2 ow0 m OO1 f ih0 k'
# change 'pOff', new pronun: 'p OO1 f'
# change 'pOng', new pronun: 'p OO1 ng'
# change 'pOniatOwski', new pronun: 'p ax n iy0 ax t OO1 f s k iy0'
# change 'pOpOff', new pronun: 'p aa1 p OO2 f'
# change 'pOppycOck', new pronun: 'p aa1 p iy0 k OO2 k'
# change 'pOrthOs', new pronun: 'p ao0 r t OO1 s'
# change 'pOsch', new pronun: 'p OO1 sh'
# change 'pOscO', new pronun: 'p OO1 s k ow0'
# change 'pOss', new pronun: 'p OO1 s'
# change 'pOsteriOr', new pronun: 'p OO2 s t ih1 r y axr'
# change 'pOstinO', new pronun: 'p OO0 s t iy1 n ow0'
# change 'pOstrel', new pronun: 'p OO1 s t r eh0 l'
# change 'pOsture', new pronun: 'p OO1 s ch axr'
# change 'pOsturing', new pronun: 'p OO1 s ch axr ih0 ng'
# change 'pOtthOff', new pronun: 'p aa1 t hh OO2 f'
# change 'prOctOlOgist', new pronun: 'p r OO0 k t aa1 l ax g ih0 s t'
# change 'prOfanatiOn', new pronun: 'p r OO2 f ax n ey1 sh ax n'
# change 'prOfligacy', new pronun: 'p r OO1 f l ih0 g ae2 s iy0'
# change 'prOfligate', new pronun: 'p r OO1 f l ih0 g ey2 t'
# change 'prOlOng', new pronun: 'p r ax l OO1 ng'
# change 'prOlOnging', new pronun: 'p r ow0 l OO1 ng ih0 ng'
# change 'prOng', new pronun: 'p r OO1 ng'
# change 'prOnger', new pronun: 'p r OO1 ng g axr'
# change 'prOnghOrn', new pronun: 'p r OO1 ng hh ao2 r n'
# change 'prOscar', new pronun: 'p r OO1 s k aa2 r'
# change 'prOsch', new pronun: 'p r OO1 sh'
# change 'prOskauer', new pronun: 'p r OO1 s k aw0 axr'
# change 'prOspect', new pronun: 'p r OO1 s p eh0 k t'
# change 'prOss', new pronun: 'p r OO1 s'
# change 'prOsser', new pronun: 'p r OO1 s axr'
# change 'prOsthesis', new pronun: 'p r OO2 s th eh1 s ih0 s'
# change 'prOsthesis', new pronun: 'p r OO2 s th iy1 s ih0 s'
# change 'pudOng', new pronun: 'p y uw1 d OO1 ng'
# change 'pudOng', new pronun: 'p uw1 d OO1 ng'
# change 'puthOff', new pronun: 'p ah1 t hh OO2 f'
# change 'pyOngyang', new pronun: 'p y OO1 ng y ae1 ng'
# changed 57 entries in P.yaml
# change 'quahOg', new pronun: 'k w aa1 hh OO2 g'
# change 'quan', new pronun: 'k w OO1 n'
# change 'quandt', new pronun: 'k w OO1 n d t'
# change 'quang', new pronun: 'k w OO1 ng'
# change 'quanticO', new pronun: 'k w OO1 n t ih0 k ow0'
# change 'quantifiable', new pronun: 'k w OO2 n t ih0 f ay1 ax b eh0 l'
# change 'quantificatiOn', new pronun: 'k w OO2 n t ih0 f ih0 k ey1 sh ax n'
# change 'quantified', new pronun: 'k w OO1 n t ih0 f ay2 d'
# change 'quantify', new pronun: 'k w OO1 n t ih0 f ay2'
# change 'quantitative', new pronun: 'k w OO1 n t ih0 t ey2 t ih0 v'
# change 'quantitatively', new pronun: 'k w OO2 n t ih0 t ey1 t ax v l iy0'
# change 'quantities', new pronun: 'k w OO1 n t ih0 t iy0 z'
# change 'quantity', new pronun: 'k w OO1 n t ih0 t iy0'
# change 'quantum', new pronun: 'k w OO1 n t ax m'
# change 'quintOn', new pronun: 'k w ih0 n t OO1 n'
# changed 16 entries in Q.yaml
# change 'rabOn', new pronun: 'r aa0 b OO1 n'
# change 'rachmaninOff', new pronun: 'r ae0 k m ae1 n ih0 n OO0 f'
# change 'radlOff', new pronun: 'r ae1 d l OO0 f'
# change 'radOsh', new pronun: 'r ax d OO1 sh'
# change 'ragOn', new pronun: 'r aa0 g OO1 n'
# change 'rakOff', new pronun: 'r ae1 k OO2 f'
# change 'ravenscrOft', new pronun: 'r ey1 v ax n z k r OO2 f t'
# change 'recOn', new pronun: 'r iy1 k OO0 n'
# change 'recOnquer', new pronun: 'r iy0 k OO1 ng k axr'
# change 'regenerOn', new pronun: 'r iy0 jh eh1 n axr OO2 n'
# change 'reggaetOn', new pronun: 'r eh2 g ey0 t OO1 n'
# change 'reOccupy', new pronun: 'r iy0 OO1 k y uw2 p ay0'
# change 'reOffend', new pronun: 'r iy0 OO0 f eh1 n d'
# change 'reOffended', new pronun: 'r iy0 OO0 f eh1 n d ih0 d'
# change 'reprOcess', new pronun: 'r iy0 p r OO1 s eh0 s'
# change 'ripOff', new pronun: 'r ih1 p OO2 f'
# change 'ripOstes', new pronun: 'r ih0 p OO1 s t s'
# change 'rOckOff', new pronun: 'r aa1 k OO2 f'
# change 'rOff', new pronun: 'r OO1 f'
# change 'rOffman', new pronun: 'r OO1 f m ax n'
# change 'rOgOff', new pronun: 'r aa1 g OO0 f'
# change 'rOgOwski', new pronun: 'r ax g OO1 f s k iy0'
# change 'rOhlOff', new pronun: 'r ow1 l OO0 f'
# change 'rOlOff', new pronun: 'r aa1 l OO0 f'
# change 'rOmanOff', new pronun: 'r ow1 m ax n OO2 f'
# change 'rOmanOv', new pronun: 'r ow1 m ax n OO2 f'
# change 'rOmanOwski', new pronun: 'r ax m ax n OO1 f s k iy0'
# change 'rOng', new pronun: 'r OO1 ng'
# change 'rOngji', new pronun: 'r OO1 ng jh iy0'
# change 'rOs', new pronun: 'r OO1 s'
# change 'rOsch', new pronun: 'r OO1 sh'
# change 'rOsenwasser', new pronun: 'r ow1 z ax n w OO0 s axr'
# change 'rOsh', new pronun: 'r OO1 sh'
# change 'rOsOff', new pronun: 'r aa1 s OO0 f'
# change 'rOss', new pronun: 'r OO1 s'
# change 'rOssbach', new pronun: 'r OO1 s b aa0 k'
# change 'rOssen', new pronun: 'r OO1 s ax n'
# change 'rOsser', new pronun: 'r OO1 s axr'
# change 'rOssi', new pronun: 'r OO1 s iy0'
# change 'rOssie', new pronun: 'r OO1 s iy0'
# change 'rOssiter', new pronun: 'r OO1 s ih0 t axr'
# change 'rOssiya', new pronun: 'r OO1 s iy0 ax'
# change 'rOssman', new pronun: 'r OO1 s m ax n'
# change 'rOssmann', new pronun: 'r OO1 s m ax n'
# change 'rOstenkOwski', new pronun: 'r OO2 s t eh0 ng k aw1 s k iy0'
# change 'rOstrOpOvich', new pronun: 'r OO2 s t r ax p ow1 v ih0 ch'
# change 'rOth', new pronun: 'r OO1 th'
# change 'rOthbard', new pronun: 'r OO1 th b axr d'
# change 'rOthbart', new pronun: 'r OO1 th b aa2 r t'
# change 'rOthberg', new pronun: 'r OO1 th b axr g'
# change 'rOthchild', new pronun: 'r OO1 th ch ay2 l d'
# change 'rOthenberg', new pronun: 'r OO1 th ax n b axr g'
# change 'rOthenberger', new pronun: 'r OO1 th ax n b axr g axr'
# change 'rOther', new pronun: 'r OO1 th axr'
# change 'rOthfuss', new pronun: 'r OO1 th f ax s'
# change 'rOthkOpf', new pronun: 'r OO1 th k ao0 p f'
# change 'rOthman', new pronun: 'r OO1 th m ax n'
# change 'rOthmans's', new pronun: 'r OO1 th m ax n z ' ih0 z'
# change 'rOthrOck', new pronun: 'r OO1 th r ax k'
# change 'rOthschild', new pronun: 'r OO1 th s ch ay2 l d'
# change 'rOthschild's', new pronun: 'r OO1 th ch ay2 l d ' z'
# change 'rOthschilds', new pronun: 'r OO1 th ch ay2 l d z'
# change 'rOthstein', new pronun: 'r OO1 th s t ay2 n'
# change 'rOthwell', new pronun: 'r OO1 th w eh2 l'
# change 'rubicOn', new pronun: 'r uw1 b ih0 k OO0 n'
# change 'runOff', new pronun: 'r ah1 n OO2 f'
# change 'ruOff', new pronun: 'r uw1 OO0 f'
# change 'rutkOwski', new pronun: 'r ax t k OO1 f s k iy0'
# changed 68 entries in R.yaml
# change 'saathOff', new pronun: 's aa1 t hh OO2 f'
# change 'sadOff', new pronun: 's ae1 d OO2 f'
# change 'sadOwski', new pronun: 's ax d OO1 f s k iy0'
# change 'salmerOn', new pronun: 's aa0 l m eh0 r OO1 n'
# change 'salOnga', new pronun: 's ax l OO1 ng g ax'
# change 'sandOn', new pronun: 's ae1 n d OO2 n'
# change 'saratOv', new pronun: 's eh1 r ax t OO2 f'
# change 'sarnOff', new pronun: 's aa1 r n OO0 f'
# change 'sarOng', new pronun: 's axr OO1 ng'
# change 'saskatchewan', new pronun: 's ae0 s k ae1 ch ax w OO2 n'
# change 'saviOn', new pronun: 's ae1 v iy0 OO0 n'
# change 'savOn', new pronun: 's ey1 v OO0 n'
# change 'schlOss', new pronun: 'sh l OO1 s'
# change 'schlOssberg', new pronun: 'sh l OO1 s b axr g'
# change 'schlOsser', new pronun: 'sh l OO1 s axr'
# change 'schlOssman', new pronun: 'sh l OO1 s m ax n'
# change 'schOff', new pronun: 'sh OO1 f'
# change 'schOffstall', new pronun: 'sh OO1 f s t ax l'
# change 'schrOff', new pronun: 'sh r OO1 f'
# change 'schrOth', new pronun: 'sh r OO1 th'
# change 'schwan', new pronun: 'sh w OO1 n'
# change 'schwandt', new pronun: 'sh w OO1 n t'
# change 'schwanz', new pronun: 'sh w OO1 n s'
# change 'scOff', new pronun: 's k OO1 f'
# change 'scOwcrOft', new pronun: 's k ow1 k r OO2 f t'
# change 'sellOff', new pronun: 's eh1 l OO2 f'
# change 'semicOlOn', new pronun: 's eh2 m ay0 k ow1 l OO0 n'
# change 'shawcrOss', new pronun: 'sh ao1 k r OO2 s'
# change 'shOffner', new pronun: 'sh OO1 f n axr'
# change 'shOstakOvich', new pronun: 'sh OO2 s t ax k ow1 v ih0 ch'
# change 'shrOff', new pronun: 'sh r OO1 f'
# change 'siObhan', new pronun: 'sh ih0 v OO1 n'
# change 'slOss', new pronun: 's l OO1 s'
# change 'smirnOff', new pronun: 's m er1 n OO0 f'
# change 'smOggy', new pronun: 's m OO1 g iy0'
# change 'snOg', new pronun: 's n OO1 g'
# change 'sOffer', new pronun: 's OO1 f axr'
# change 'sOffit', new pronun: 's OO1 f ih0 t'
# change 'sOft', new pronun: 's OO1 f t'
# change 'sOftball', new pronun: 's OO1 f t b ao2 l'
# change 'sOftbank', new pronun: 's OO1 f t b ae2 ng k'
# change 'sOftdrink', new pronun: 's OO1 f t d r ih2 ng k'
# change 'sOftech', new pronun: 's OO1 f t eh2 k'
# change 'sOften', new pronun: 's OO1 f ax n'
# change 'sOftener', new pronun: 's OO1 f ax n axr'
# change 'sOfter', new pronun: 's OO1 f t axr'
# change 'sOftest', new pronun: 's OO1 f t ih0 s t'
# change 'sOftimage', new pronun: 's OO1 f t ih2 m ih0 jh'
# change 'sOftkey', new pronun: 's OO1 f t k ey2'
# change 'sOftness', new pronun: 's OO1 f t n ax s'
# change 'sOftsOap', new pronun: 's OO1 f t s ow2 p'
# change 'sOftware', new pronun: 's OO1 f t w eh2 r'
# change 'sOftwOOd', new pronun: 's OO1 f t w uh2 d'
# change 'sOkOlOff', new pronun: 's aa1 k ax l OO0 f'
# change 'sOkOlOwski', new pronun: 's ax k ax l OO1 f s k iy0'
# change 'sOlOff', new pronun: 's aa1 l OO0 f'
# change 'sOnet', new pronun: 's OO1 n ih0 t'
# change 'sOng', new pronun: 's OO1 ng'
# change 'sOngbird', new pronun: 's OO1 ng b er2 d'
# change 'sOngbOOk', new pronun: 's OO1 ng b uh2 k'
# change 'sOnger', new pronun: 's OO1 ng axr'
# change 'sOngwriter', new pronun: 's OO1 ng r ay2 t axr'
# change 'sOngwriting', new pronun: 's OO1 ng r ay2 t ih0 ng'
# change 'sOnOgram', new pronun: 's OO1 n ax g r ae2 m'
# change 'sOphistry', new pronun: 's OO1 f ih0 s t r iy0'
# change 'sOsnOwski', new pronun: 's ax s n OO1 f s k iy0'
# change 'sOss', new pronun: 's OO1 s'
# change 'sOssamOn', new pronun: 's ow0 s aa0 m OO1 n'
# change 'spinOff', new pronun: 's p ih1 n OO2 f'
# change 'spOng', new pronun: 's p OO1 ng'
# change 'ssangyOng', new pronun: 's ae1 ng y OO2 ng'
# change 'standOff', new pronun: 's t ae1 n d OO2 f'
# change 'stankOwski', new pronun: 's t ax ng k OO1 f s k iy0'
# change 'staphylOcOccus', new pronun: 's t ae2 f ax l ax k OO1 k ax s'
# change 'starcrOss', new pronun: 's t aa1 r k r OO2 s'
# change 'steinhOff', new pronun: 's t ay1 n hh OO2 f'
# change 'stellenbOsch', new pronun: 's t eh1 l ax n b OO2 sh'
# change 'stOff', new pronun: 's t OO1 f'
# change 'stOffer', new pronun: 's t OO1 f axr'
# change 'stOng', new pronun: 's t OO1 ng'
# change 'streptOcOccus', new pronun: 's t r eh2 p t ow0 k OO1 k ax s'
# change 'strOganOff', new pronun: 's t r ow1 g ax n OO2 f'
# change 'strOng', new pronun: 's t r OO1 ng'
# change 'strOnger', new pronun: 's t r OO1 ng g axr'
# change 'strOngest', new pronun: 's t r OO1 ng g ih0 s t'
# change 'strOnghOld', new pronun: 's t r OO1 ng hh ow2 l d'
# change 'strOngman', new pronun: 's t r OO1 ng m ae2 n'
# change 'strOssen', new pronun: 's t r OO1 s eh0 n'
# change 'strOssen', new pronun: 's t r OO1 s ih0 n'
# change 'styrOn', new pronun: 's t ay1 r OO0 n'
# change 'sulkOwski', new pronun: 's ax l k OO1 f s k iy0'
# change 'swaney', new pronun: 's w OO1 n iy0'
# change 'swanger', new pronun: 's w OO1 ng axr'
# change 'swansOn', new pronun: 's w OO1 n s ax n'
# change 'swanstrOm', new pronun: 's w OO1 n s t r ax m'
# change 'swantOn', new pronun: 's w OO1 n t ax n'
# change 'synagOgue', new pronun: 's ih1 n ax g OO2 g'
# change 'szymanOwski', new pronun: 'sh ih0 m ax n OO1 f s k iy0'
# changed 97 entries in S.yaml
# change 'tableclOth', new pronun: 't ey1 b ax l k l OO2 th'
# change 'takeOff', new pronun: 't ey1 k OO2 f'
# change 'tarnOwski', new pronun: 't axr n OO1 f s k iy0'
# change 'terrebOnne', new pronun: 't eh2 r ax b OO1 n'
# change 'teutOnic', new pronun: 't uw0 t OO1 n ih0 k'
# change 'thereOn', new pronun: 'dh eh0 r OO1 n'
# change 'thOng', new pronun: 'th OO1 ng'
# change 'thrOng', new pronun: 'th r OO1 ng'
# change 'tiburOn', new pronun: 't iy1 b ah0 r OO2 n'
# change 'tipOff', new pronun: 't ih1 p OO2 f'
# change 'tOff', new pronun: 't OO1 f'
# change 'tOffee', new pronun: 't OO1 f iy0'
# change 'tOffler', new pronun: 't OO1 f l axr'
# change 'tOng', new pronun: 't OO1 ng'
# change 'tOnga', new pronun: 't OO1 ng g ax'
# change 'tOnge', new pronun: 't OO1 n jh'
# change 'tOnk', new pronun: 't OO1 ng k'
# change 'tOnsil', new pronun: 't OO1 n s ih0 l'
# change 'tOnsillectOmy', new pronun: 't OO2 n s ih0 l eh1 k t ax m iy0'
# change 'tOOlbOx', new pronun: 't uw1 l b OO2 k s'
# change 'tOsca', new pronun: 't OO1 s k ax'
# change 'tOscanini', new pronun: 't OO2 s k ax n iy1 n iy0'
# change 'tOscO', new pronun: 't OO1 s k ow0'
# change 'tOss', new pronun: 't OO1 s'
# change 'tOsses', new pronun: 't OO1 s ih0 z'
# change 'tOsti', new pronun: 't OO1 s t iy0'
# change 'tradeOff', new pronun: 't r ey1 d OO2 f'
# change 'travelOgue', new pronun: 't r ae1 v ax l OO2 g'
# change 'trOjanOwski', new pronun: 't r ax y ax n OO1 f s k iy0'
# change 'trOth', new pronun: 't r OO1 th'
# change 'trOugh', new pronun: 't r OO1 f'
# change 'truOng', new pronun: 't r OO1 ng'
# change 'tsOngas', new pronun: 't s OO1 ng g ax s'
# change 'tsOngas', new pronun: 's OO1 ng g ax s'
# change 'turnOff', new pronun: 't er1 n OO2 f'
# changed 34 entries in T.yaml
# change 'ueberrOth', new pronun: 'y uw1 b axr r OO2 th'
# change 'unbOx', new pronun: 'ah0 n b OO1 k s'
# change 'uncOntradicted', new pronun: 'ah2 ng k OO0 n t r ax d ih1 k t ih0 d'
# change 'underdOg', new pronun: 'ah1 n d axr d OO2 g'
# change 'undergOne', new pronun: 'ah2 n d axr g OO1 n'
# change 'unprOcessed', new pronun: 'ah0 n p r OO1 s eh2 s t'
# change 'unwanted', new pronun: 'ah0 n w OO1 n t ih0 d'
# change 'uphOff', new pronun: 'ah1 p hh OO2 f'
# changed 8 entries in U.yaml
# change 'valdOsta', new pronun: 'v ae2 l d OO1 s t ax'
# change 'vandrOss', new pronun: 'v ae2 n d r OO1 s'
# change 'vardOn', new pronun: 'v aa0 r d OO1 n'
# change 'varOn', new pronun: 'v aa0 r OO1 n'
# change 'velOciraptOr', new pronun: 'v ax l OO1 s ax r ae2 p t axr'
# change 'verdOn', new pronun: 'v eh0 r d OO1 n'
# change 'verhOfstadt', new pronun: 'v axr hh OO1 f s t ae2 t'
# change 'videOgrapher', new pronun: 'v ih0 d iy0 OO1 g r ax f axr'
# change 'vietcOng', new pronun: 'v iy0 eh1 t k OO1 ng'
# change 'villalOn', new pronun: 'v iy0 l aa0 l OO1 n'
# change 'visclOsky', new pronun: 'v ih0 s k l OO1 s k iy0'
# change 'vladivOstOk', new pronun: 'v l ae2 d ih0 v OO1 s t aa0 k'
# change 'vlahOs', new pronun: 'v l aa1 hh OO0 s'
# change 'vOgelsOng', new pronun: 'v aa1 g ih0 l s OO0 ng'
# change 'vOn', new pronun: 'v OO1 n'
# change 'vOng', new pronun: 'v OO1 ng'
# change 'vOss', new pronun: 'v OO1 s'
# change 'vOssen', new pronun: 'v OO1 s ax n'
# change 'vuittOn', new pronun: 'v uh2 t OO1 n'
# change 'vuOng', new pronun: 'v uw0 OO1 ng'
# changed 20 entries in V.yaml
# change 'wachOwski', new pronun: 'v ax hh OO1 f s k iy0'
# change 'wachs', new pronun: 'w OO1 k s'
# change 'wachsman', new pronun: 'w OO1 k s m ax n'
# change 'wachsmuth', new pronun: 'w OO1 k s m uh0 th'
# change 'wachter', new pronun: 'w OO1 k t axr'
# change 'wander', new pronun: 'w OO1 n d axr'
# change 'wanderer', new pronun: 'w OO1 n d axr axr'
# change 'wanderlust', new pronun: 'w OO1 n d axr l ah2 s t'
# change 'wangerin', new pronun: 'w OO1 ng g axr ih0 n'
# change 'wansley', new pronun: 'w OO1 n z l iy0'
# change 'want', new pronun: 'w OO1 n t'
# change 'wanted', new pronun: 'w OO1 n t ih0 d'
# change 'wantOn', new pronun: 'w OO1 n t ax n'
# change 'warlOck', new pronun: 'w ao1 r l OO2 k'
# change 'wascO', new pronun: 'w OO1 s k ow0'
# change 'wash', new pronun: 'w OO1 sh'
# change 'washable', new pronun: 'w OO1 sh ax b ax l'
# change 'washbasin', new pronun: 'w OO1 sh b ey2 s ax n'
# change 'washbOard', new pronun: 'w OO1 sh b ao2 r d'
# change 'washburn', new pronun: 'w OO1 sh b er2 n'
# change 'washburne', new pronun: 'w OO1 sh b er2 n'
# change 'washclOth', new pronun: 'w OO1 sh k l OO2 th'
# change 'washer', new pronun: 'w OO1 sh axr'
# change 'washes', new pronun: 'w OO1 sh ih0 z'
# change 'washingtOn', new pronun: 'w OO1 sh ih0 ng t ax n'
# change 'washingtOnian', new pronun: 'w OO2 sh ih0 ng t ow1 n iy0 ax n'
# change 'wasley', new pronun: 'w OO1 s l iy0'
# change 'wasmer', new pronun: 'w OO1 s ax m axr'
# change 'wassell', new pronun: 'w OO1 s ax l'
# change 'wassenaar', new pronun: 'w OO1 s ih0 n aa0 r'
# change 'wasser', new pronun: 'w OO1 s axr'
# change 'wassOn', new pronun: 'w OO1 s ax n'
# change 'watchdOg', new pronun: 'w ao1 ch d OO2 g'
# change 'wathen', new pronun: 'w OO1 th ax n'
# change 'weeklOng', new pronun: 'w iy1 k l OO2 ng'
# change 'wesOlOwski', new pronun: 'v ih0 s ax l OO1 f s k iy0'
# change 'westerhOff', new pronun: 'w eh1 s t axr hh OO2 f'
# change 'westhOff', new pronun: 'w eh1 s t hh OO2 f'
# change 'wilfOng', new pronun: 'w ih1 l f OO0 ng'
# change 'witkOwski', new pronun: 'v ih0 t k OO1 f s k iy0'
# change 'wOebegOne', new pronun: 'w ow1 b ih0 g OO2 n'
# change 'wOjciechOwski', new pronun: 'w oy0 ch ih0 hh OO1 f s k iy0'
# change 'wOnd', new pronun: 'w OO1 n d'
# change 'wOng', new pronun: 'w OO1 ng'
# change 'wOnt', new pronun: 'w OO1 n t'
# change 'wrOng', new pronun: 'r OO1 ng'
# change 'wrOngdOer', new pronun: 'r OO1 ng d uw1 axr'
# change 'wrOngdOing', new pronun: 'r OO1 ng d uw0 ih0 ng'
# change 'wrOngdOings', new pronun: 'r OO0 ng d uw1 ih0 ng z'
# change 'wrOngful', new pronun: 'r OO1 ng f ax l'
# change 'wrOngheaded', new pronun: 'r OO1 ng hh eh2 d ih0 d'
# change 'wyckOff', new pronun: 'w ih1 k OO0 f'
# change 'wycOff', new pronun: 'w ih1 k OO0 f'
# change 'wykOff', new pronun: 'w ih1 k OO0 f'
# change 'wysOng', new pronun: 'w ih1 s OO0 ng'
# changed 55 entries in W.yaml
# change 'xiOng', new pronun: 'zh OO1 ng'
# change 'xudOng', new pronun: 'z uw1 d OO1 ng'
# change 'xudOng', new pronun: 'zh w ey1 d OO1 ng'
# changed 2 entries in X.yaml
# change 'yankOwski', new pronun: 'y ax ng k OO1 f s k iy0'
# change 'yearlOng', new pronun: 'y ih1 r l OO1 ng'
# change 'yOest', new pronun: 'y OO1 s t'
# change 'yOffie', new pronun: 'y OO1 f iy0'
# change 'yOng', new pronun: 'y OO1 ng'
# change 'yOngbyOn', new pronun: 'y OO1 ng b y OO1 n'
# changed 6 entries in Y.yaml
# change 'zebrOwski', new pronun: 'z ax b r OO1 f s k iy0'
# change 'zedOng', new pronun: 'z ih0 d OO1 ng'
# change 'ziOlkOwski', new pronun: 'z iy0 ow0 l k OO1 f s k iy0'
# change 'zOgby', new pronun: 'z OO1 g b iy0'
# change 'zOn', new pronun: 'z OO1 n'
# change 'zubOff', new pronun: 'z uw1 b OO0 f'
# change 'zukOwski', new pronun: 'z ax k OO1 f s k iy0'
# change 'zwack', new pronun: 'z w OO1 k'
# changed 8 entries in Z.yaml
# nothing changed or removed in _other.yaml

# %%
to_remove = """
coutant
"""

# %%
w = 'AWFOFF'
p = 'AO1 F AO2 F'
# w = 'xBLOGOSPHERE'
# p = 'B L AO1 G AO0 S F IH1 R'

# %%
change_to_cloth_vowel(w, p, {})
# Out:
# probably no candiate 'AWFOFF', indices: [3], 0
# possibly a candiate  'AWFOFF', new pronun: 'AO1 F OA2 F'
# True

# %%
[m.start() for m in re.finditer('o', 'blogo')]
# Out:
# [2, 4]

# %%
[m.start() for m in re.finditer("WA(?![UW])", "WAUSHWA")]
# Out:
# [5]

# %%
f"{'ds'}"
# Out:
# 'ds'
