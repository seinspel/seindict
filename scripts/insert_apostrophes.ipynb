# %%
from __future__ import annotations
from typing import Union, List, Optional, Dict, Tuple

# %%
from pathlib import Path
from collections import OrderedDict
from strictyaml import load, MapPattern, Str, Seq

# %%
schema = MapPattern(Str(), Str() | MapPattern(Str(), Str()) | Seq(Str()))

# %%
def read_yaml_file(fpath: Path):
    """Load the content of a YAML file as an ordered dictionary"""
    raw_data = fpath.open().read()
    return load(raw_data, schema)

# %%
YAML_FILES: List[str] = [
    "A.yaml",
    "B.yaml",
    "C.yaml",
    "D.yaml",
    "E.yaml",
    "F.yaml",
    "G.yaml",
    "H.yaml",
    "I.yaml",
    "J.yaml",
    "K.yaml",
    "L.yaml",
    "M.yaml",
    "N.yaml",
    "O.yaml",
    "P.yaml",
    "Q.yaml",
    "R.yaml",
    "S.yaml",
    "T.yaml",
    "U.yaml",
    "V.yaml",
    "W.yaml",
    "X.yaml",
    "Y.yaml",
    "Z.yaml",
    "_other.yaml",
]

# %%
def has_apostrophe(word):
    return word[-2:] == "'S"

# %%
def get_new_pronun(word: str, pronun: str) -> Optional[str]:
    if pronun[-6:] == " IH0 Z":
        new_pronun = pronun[:-6] + " ' IH0 Z"
        print(f"{word}: {pronun} -> {new_pronun}")
    elif pronun[-2:] == " Z":
        new_pronun = pronun[:-2] + " ' Z"
        print(f"{word}: {pronun} -> {new_pronun}")
    elif pronun[-2:] == " S":
        new_pronun = pronun[:-2] + " ' S"
        print(f"{word}: {pronun} -> {new_pronun}")
    else:
        raise ValueError(f"S is not pronounced: {word}: {pronun}")
    return new_pronun

# %%
def insert_apostrophes(yaml_dict):
    dictionary = yaml_dict.data
    counter = 0
    for word, value in dictionary.items():
        if not has_apostrophe(word):
            continue
        if isinstance(value, str):
            pronun: str = value
            if "'" in pronun:
                print(f"{word} already has an apostrophe")
            else:
                yaml_dict[word] = get_new_pronun(word, pronun)
        else:
            if isinstance(value, list):
                pronun_list: List[str] = value
                new_pronuns = []
                for pronun in pronun_list:
                    new_pronuns.append(get_new_pronun(word, pronun))
                if "'" in pronun:
                    print(f"{word} already has an apostrophe")
                else:
                    yaml_dict[word] = new_pronuns
            elif isinstance(value, OrderedDict):
                pronun_dict: OrderedDict[str, str] = value
                new_pronuns = OrderedDict()
                for k, pronun in pronun_dict.items():
                    new_pronuns[k] = get_new_pronun(word, pronun)
                if "'" in pronun:
                    print(f"{word} already has an apostrophe")
                else:
                    yaml_dict[word] = new_pronuns
            else:
                raise ValueError(f"unexpected type: {type(value)}")
        counter += 1
    return counter

# %%
base_path = Path("..") / "dictionary"
for yaml_file in YAML_FILES:
    yaml_path = base_path / yaml_file
    yaml_dict = read_yaml_file(yaml_path)
    num_changed = insert_apostrophes(yaml_dict)
    print(f"changed {num_changed} entries in {yaml_file}")
    yaml_path.open("w").write(yaml_dict.as_yaml())
# Out:
# ABRAM'S already has an apostrophe
# ACCOR'S already has an apostrophe
# ADMINISTRATOR'S already has an apostrophe
# AINSWORTH'S already has an apostrophe
# AIRCAL'S already has an apostrophe
# AIRPLANE'S already has an apostrophe
# AIRWAYS'S already has an apostrophe
# AKERS'S already has an apostrophe
# ALCOA'S already has an apostrophe
# ALYESKA'S already has an apostrophe
# AMES'S already has an apostrophe
# AMEX'S already has an apostrophe
# AMTRAK'S already has an apostrophe
# ANDREW'S already has an apostrophe
# ANHEUSER'S already has an apostrophe
# ANTIGONE'S already has an apostrophe
# ANTONIU'S already has an apostrophe
# APARTHEID'S already has an apostrophe
# ARAFAT'S already has an apostrophe
# ARIAS'S already has an apostrophe
# ASKERS'S already has an apostrophe
# ASKIN'S already has an apostrophe
# ASPIRIN'S already has an apostrophe
# AVON'S already has an apostrophe
# AYER'S: EH1 R ' Z -> EH1 R ' ' Z
# AYER'S: EY1 R ' Z -> EY1 R ' ' Z
# AYER'S already has an apostrophe
# changed 25 entries in A.yaml
# BADEN'S: B AA1 D AX N Z -> B AA1 D AX N ' Z
# BALT'S: B AO1 L T S -> B AO1 L T ' S
# BANCROFT'S: B AE1 NG K R AO2 F T S -> B AE1 NG K R AO2 F T ' S
# BANKS'S: B AE1 NG K S IH0 Z -> B AE1 NG K S ' IH0 Z
# BANQUO'S: B AE1 NG K W OW0 Z -> B AE1 NG K W OW0 ' Z
# BARCLAY'S: B AA1 R K L EY0 Z -> B AA1 R K L EY0 ' Z
# BARCLAYS'S: B AA1 R K L EY0 Z -> B AA1 R K L EY0 ' Z
# BEEBA'S: B IY1 B AX Z -> B IY1 B AX ' Z
# BEERS'S: B IH1 R Z IH0 Z -> B IH1 R Z ' IH0 Z
# BELGIQUE'S: B EH0 L JH IY1 K S -> B EH0 L JH IY1 K ' S
# BERLET'S: B ER1 L EH1 T S -> B ER1 L EH1 T ' S
# BESCHLOSS'S: B EH1 SH L AO2 S IH0 S -> B EH1 SH L AO2 S IH0 ' S
# BOATMEN'S: B OW1 T M EH0 N Z -> B OW1 T M EH0 N ' Z
# BOLTZMANN'S: B OW1 L T S M AX N Z -> B OW1 L T S M AX N ' Z
# BRAHMS'S: B R AA1 M Z IH0 Z -> B R AA1 M Z ' IH0 Z
# BRANDS'S: B R AE1 N D Z IH0 Z -> B R AE1 N D Z ' IH0 Z
# BRANSON'S: B R AE1 N S AH2 N Z -> B R AE1 N S AH2 N ' Z
# BROOKS'S: B R UH1 K S IH0 Z -> B R UH1 K S ' IH0 Z
# BROOKS'S: B R UH1 K S -> B R UH1 K ' S
# BROTHERS'S: B R AH1 DH AXR Z IH0 Z -> B R AH1 DH AXR Z ' IH0 Z
# BURBANK'S: B ER1 B AE0 NG K S -> B ER1 B AE0 NG K ' S
# BURNS'S: B ER1 N Z IH0 Z -> B ER1 N Z ' IH0 Z
# changed 21 entries in B.yaml
# CALIFORNIA'S: K AE2 L IH0 F AO1 R N Y AX Z -> K AE2 L IH0 F AO1 R N Y AX ' Z
# CALLAWAY'S: K AO1 L AX W EY2 Z -> K AO1 L AX W EY2 ' Z
# CAPEL'S: K AE1 P AX L Z -> K AE1 P AX L ' Z
# CARLYLE'S: K AA0 R L AY1 L Z -> K AA0 R L AY1 L ' Z
# CAROLCO'S: K EH1 R AX L K OW0 Z -> K EH1 R AX L K OW0 ' Z
# CARRIERS'S: K EH1 R IY0 AXR Z IH0 Z -> K EH1 R IY0 AXR Z ' IH0 Z
# CARTERET'S: K AA2 R T AXR EH1 T S -> K AA2 R T AXR EH1 T ' S
# CATACOSINOS'S: K AX T AE2 K AX S IY1 N AX S IH0 Z -> K AX T AE2 K AX S IY1 N AX S ' IH0 Z
# CEDRAS'S: S EY1 D R AA2 S IH0 S -> S EY1 D R AA2 S IH0 ' S
# CEDRAS'S: S EY1 D R AX S IH0 S -> S EY1 D R AX S IH0 ' S
# CHAMBERS'S: CH EY1 M B AXR Z IH0 Z -> CH EY1 M B AXR Z ' IH0 Z
# CHANNELL'S: SH AX N EH1 L Z -> SH AX N EH1 L ' Z
# CHARLES'S: CH AA1 R L Z IH0 Z -> CH AA1 R L Z ' IH0 Z
# CHILES'S: CH IH1 L IY0 Z IH0 Z -> CH IH1 L IY0 Z ' IH0 Z
# CHIROPRACTOR'S: K AY1 R OW0 P R AE2 K T AXR Z -> K AY1 R OW0 P R AE2 K T AXR ' Z
# CINCINNATI'S: S IH2 N S IH0 N AE1 T IY0 Z -> S IH2 N S IH0 N AE1 T IY0 ' Z
# CLINES'S: K L AY1 N Z IH0 Z -> K L AY1 N Z ' IH0 Z
# COLLINS'S: K AA1 L IH0 N Z IH0 Z -> K AA1 L IH0 N Z ' IH0 Z
# COLLINS'S: K AA1 L IH0 N Z -> K AA1 L IH0 N ' Z
# COMMERZBANK'S: K AA1 M AXR Z B AE1 NG K S -> K AA1 M AXR Z B AE1 NG K ' S
# COMPANIES'S: K AH1 M P AX N IY0 Z -> K AH1 M P AX N IY0 ' Z
# CONSTITUTION'S: K AA2 N S T IH0 T UW1 SH AX N Z -> K AA2 N S T IH0 T UW1 SH AX N ' Z
# COSMO'S: K AA1 Z M OW0 Z -> K AA1 Z M OW0 ' Z
# COWLINGS'S: K AW1 L IH0 NG Z IH0 Z -> K AW1 L IH0 NG Z ' IH0 Z
# CROMWELL'S: K R AA1 M W IH0 L Z -> K R AA1 M W IH0 L ' Z
# CROSSFIRE'S: K R AO1 S F AY0 R Z -> K R AO1 S F AY0 R ' Z
# CROWTHER'S: K R OW1 TH AXR Z -> K R OW1 TH AXR ' Z
# CUCKOO'S: K UW1 K UW0 Z -> K UW1 K UW0 ' Z
# changed 26 entries in C.yaml
# DANIELS'S: D AE1 N Y AX L Z IH0 Z -> D AE1 N Y AX L Z ' IH0 Z
# DANIELS'S: D AE2 N Y EH1 L Z IH0 Z -> D AE2 N Y EH1 L Z ' IH0 Z
# DANTE'S: D AE1 N T IY0 Z -> D AE1 N T IY0 ' Z
# DAVIO'S: D AE1 V IY0 OW0 Z -> D AE1 V IY0 OW0 ' Z
# DELEGATE'S: D EH1 L IH0 G IH0 T S -> D EH1 L IH0 G IH0 T ' S
# DESPINA'S: D EH1 S P IY0 N AX Z -> D EH1 S P IY0 N AX ' Z
# DETERMINATION'S: D IH0 T ER2 M IH0 N EY1 SH AX N Z -> D IH0 T ER2 M IH0 N EY1 SH AX N ' Z
# DEVILLIER'S: D IH0 V IH1 L Y AXR S -> D IH0 V IH1 L Y AXR ' S
# DICKENS'S: D IH1 K AX N Z IH0 Z -> D IH1 K AX N Z ' IH0 Z
# DIEGO'S: D IY2 EY1 G OW0 Z -> D IY2 EY1 G OW0 ' Z
# DIMITRIUS'S: D IH0 M IY1 T R IY0 AX S IH0 S -> D IH0 M IY1 T R IY0 AX S IH0 ' S
# DISTILLERS'S: D IH0 S T IH1 L AXR Z IH0 Z -> D IH0 S T IH1 L AXR Z ' IH0 Z
# DISTRIBUTOR'S: D IH0 S T R IH1 B Y UW0 T AXR Z -> D IH0 S T R IH1 B Y UW0 T AXR ' Z
# DOLES'S: D OW1 L Z IH0 Z -> D OW1 L Z ' IH0 Z
# DONIZETTI'S: D AA2 N IH0 Z EH1 T IY0 Z -> D AA2 N IH0 Z EH1 T IY0 ' Z
# DOWNES'S: D AW1 N Z IH0 Z -> D AW1 N Z ' IH0 Z
# DRUMLIN'S: D R AH1 M L IH0 N Z -> D R AH1 M L IH0 N ' Z
# DURAN'S: D AXR AE1 N S -> D AXR AE1 N ' S
# DURANT'S: D AXR AE1 N T S -> D AXR AE1 N T ' S
# DYNAMICS'S: D AY0 N AE1 M IH0 K S IH0 Z -> D AY0 N AE1 M IH0 K S ' IH0 Z
# changed 19 entries in D.yaml
# EDWARDS'S: EH1 D W AXR D Z IH0 Z -> EH1 D W AXR D Z ' IH0 Z
# ELDERS'S: EH1 L D AXR Z IH0 Z -> EH1 L D AXR Z ' IH0 Z
# ENGINEER'S: EH2 N JH AX N IH1 R Z -> EH2 N JH AX N IH1 R ' Z
# ETHNOS'S: EH1 TH N AX S IH0 Z -> EH1 TH N AX S ' IH0 Z
# EUROTUNNEL'S: Y UH1 R OW0 T AH2 N AX L Z -> Y UH1 R OW0 T AH2 N AX L ' Z
# EVANS'S: EH1 V AX N Z IH0 Z -> EH1 V AX N Z ' IH0 Z
# changed 6 entries in E.yaml
# FARMERS'S: F AA1 R M AXR Z IH0 Z -> F AA1 R M AXR Z ' IH0 Z
# FEDDERS'S: F EH1 D AXR Z IH0 Z -> F EH1 D AXR Z ' IH0 Z
# FERRUZZI'S: F ER2 UW1 Z IY0 Z -> F ER2 UW1 Z IY0 ' Z
# FIAT'S: F IY1 AE2 T S -> F IY1 AE2 T ' S
# FIREBUSH'S: F AY1 R B UH2 SH IH0 Z -> F AY1 R B UH2 SH ' IH0 Z
# FRANKLIN'S: F R AE1 NG K L AX N Z -> F R AE1 NG K L AX N ' Z
# changed 6 entries in F.yaml
# G'VANNI'S: JH IY2 OW0 V AA1 N IY0 Z -> JH IY2 OW0 V AA1 N IY0 ' Z
# GANNETT'S: G AE1 N AX T S -> G AE1 N AX T ' S
# GARCIA'S: G AA0 R S IY1 AX Z -> G AA0 R S IY1 AX ' Z
# GARRET'S: G EH1 R AX T S -> G EH1 R AX T ' S
# GATES'S: G EY1 T S IH0 Z -> G EY1 T S ' IH0 Z
# GATES'S: G EY1 T S -> G EY1 T ' S
# GENTLEMAN'S: JH EH1 N T AX L M AH2 N Z -> JH EH1 N T AX L M AH2 N ' Z
# GENTLEMEN'S: JH EH1 N T AX L M EH2 N Z -> JH EH1 N T AX L M EH2 N ' Z
# GIA'S: JH IY1 AX Z -> JH IY1 AX ' Z
# GIACONDA'S: JH IY1 AX K AA1 N D AX Z -> JH IY1 AX K AA1 N D AX ' Z
# GIBB'S: G IH1 B Z -> G IH1 B ' Z
# GIVENS'S: G IH1 V AX N Z IH0 Z -> G IH1 V AX N Z ' IH0 Z
# GLICKMAN'S: G L IH1 K S M AX N Z -> G L IH1 K S M AX N ' Z
# GOLDINI'S: G OW0 L D IY1 N IY0 Z -> G OW0 L D IY1 N IY0 ' Z
# GOODMAN'S: G UH1 D M AE2 N Z -> G UH1 D M AE2 N ' Z
# GOODSPEED'S: G UH1 D S P IY1 D Z -> G UH1 D S P IY1 D ' Z
# GRANDMA'S: G R AE1 N D M AA2 Z -> G R AE1 N D M AA2 ' Z
# GRANDPA'S: G R AE1 N P AA2 Z -> G R AE1 N P AA2 ' Z
# GRAVES'S: G R EY1 V Z IH0 Z -> G R EY1 V Z ' IH0 Z
# GUBA'S: G Y UW1 B AX Z -> G Y UW1 B AX ' Z
# changed 19 entries in G.yaml
# HALLMARK'S: HH AO1 L M AA2 R K S -> HH AO1 L M AA2 R K ' S
# HAMMAS'S: HH AX M AA1 S IH0 S -> HH AX M AA1 S IH0 ' S
# HANOI'S: HH AX N OY1 Z -> HH AX N OY1 ' Z
# HARCOURT'S: HH AA1 R K AXR T S -> HH AA1 R K AXR T ' S
# HARDING'S: HH AA1 R D IH0 NG S -> HH AA1 R D IH0 NG ' S
# HEIDI'S: HH AY1 D IY0 S -> HH AY1 D IY0 ' S
# HELMS'S: HH EH1 L M Z IH0 Z -> HH EH1 L M Z ' IH0 Z
# HOFFENBERG'S: HH AA1 F AX N B AXR G Z -> HH AA1 F AX N B AXR G ' Z
# HONDA'S: HH AA1 N D AX Z -> HH AA1 N D AX ' Z
# HORATIO'S: HH AO0 R EY1 SH IY0 OW0 Z -> HH AO0 R EY1 SH IY0 OW0 ' Z
# HORNET'S: HH AO1 R N AX T S -> HH AO1 R N AX T ' S
# HSIUNG'S: SH Y AH1 NG Z -> SH Y AH1 NG ' Z
# changed 12 entries in H.yaml
# ILALIS'S: IH2 L AE1 L AX S IH0 S -> IH2 L AE1 L AX S IH0 ' S
# ILLINOIS'S: IH2 L IH0 N OY1 Z -> IH2 L IH0 N OY1 ' Z
# INCO'S: IH1 NG K OW0 Z -> IH1 NG K OW0 ' Z
# INLAND'S: IH1 N L AX N D Z -> IH1 N L AX N D ' Z
# INSTITUTE'S: IH1 N S T IH0 T UW0 T S -> IH1 N S T IH0 T UW0 T ' S
# INSTITUTION'S: IH0 N S T IH0 T UW1 SH AX N Z -> IH0 N S T IH0 T UW1 SH AX N ' Z
# INVESCO'S: IH2 N V EH1 S OW0 Z -> IH2 N V EH1 S OW0 ' Z
# IONICS'S: AY2 AA1 N IH0 K S -> AY2 AA1 N IH0 K ' S
# IRENE'S: AY2 R IY1 N Z -> AY2 R IY1 N ' Z
# changed 9 entries in I.yaml
# JACOBS'S: JH EY1 K AX B Z IH0 Z -> JH EY1 K AX B Z ' IH0 Z
# JAFFRAY'S: JH AE1 F R EY2 Z -> JH AE1 F R EY2 ' Z
# JENRETTE'S: JH EH0 N R EH1 T S -> JH EH0 N R EH1 T ' S
# JIMBO'S: JH IH1 M B OW0 Z -> JH IH1 M B OW0 ' Z
# JOBS'S: JH AA1 B Z IH0 Z -> JH AA1 B Z ' IH0 Z
# JOHNS'S: JH AA1 N Z IH0 Z -> JH AA1 N Z ' IH0 Z
# JONBENET'S: JH AO1 N B AX N EY1 S -> JH AO1 N B AX N EY1 ' S
# JONES'S: JH OW1 N Z IH0 Z -> JH OW1 N Z ' IH0 Z
# JOSHUA'S: JH AO1 SH UW2 AX Z -> JH AO1 SH UW2 AX ' Z
# JOSKE'S: JH AO1 S K IY0 Z -> JH AO1 S K IY0 ' Z
# JOURNEYMAN'S: JH ER1 N IY0 M AX N Z -> JH ER1 N IY0 M AX N ' Z
# changed 11 entries in J.yaml
# KANEMARU'S: K AA2 N EY0 M AA1 R UW0 Z -> K AA2 N EY0 M AA1 R UW0 ' Z
# KIPLINGER'S: K IH1 P L IH2 NG G AXR Z -> K IH1 P L IH2 NG G AXR ' Z
# KOSLOW'S: K AA1 Z L OW0 Z -> K AA1 Z L OW0 ' Z
# changed 3 entries in K.yaml
# LAIDLAW'S: L EY1 D L AO1 Z -> L EY1 D L AO1 ' Z
# LAURIAT'S: L AO1 R IY0 IH0 T S -> L AO1 R IY0 IH0 T ' S
# LEEDS'S: L IY1 D Z IH0 Z -> L IY1 D Z ' IH0 Z
# LEVELER'S: L EH1 V AX L AXR Z -> L EH1 V AX L AXR ' Z
# LEVELER'S: L EH1 V L AXR Z -> L EH1 V L AXR ' Z
# LIGGETT'S: L IH1 G EH2 T S -> L IH1 G EH2 T ' S
# LOCKETT'S: L AA1 K AX T S -> L AA1 K AX T ' S
# LOREAN'S: L AO0 R IY1 N Z -> L AO0 R IY1 N ' Z
# LUMBERMAN'S: L AH1 M B AXR M AE2 N Z -> L AH1 M B AXR M AE2 N ' Z
# LYBRAND'S: L AY1 B R AX N D Z -> L AY1 B R AX N D ' Z
# LYONS'S: L AY1 AX N Z IH0 Z -> L AY1 AX N Z ' IH0 Z
# changed 10 entries in L.yaml
# MACINTOSH'S: M AE1 K AX N T AA2 SH IH0 Z -> M AE1 K AX N T AA2 SH ' IH0 Z
# MAHARAJA'S: M AA0 HH AXR AA1 ZH AH2 Z -> M AA0 HH AXR AA1 ZH AH2 ' Z
# MARASH'S: M AA1 R AX SH IH0 S -> M AA1 R AX SH IH0 ' S
# MARCOS'S: M AA1 R K AX S IH0 Z -> M AA1 R K AX S ' IH0 Z
# MARKS'S: M AA1 R K S IH0 Z -> M AA1 R K S ' IH0 Z
# MARLBORO'S: M AA1 R L B AXR R OW0 Z -> M AA1 R L B AXR R OW0 ' Z
# MARS'S: M AA1 R Z IH0 Z -> M AA1 R Z ' IH0 Z
# MARTENS'S: M AA1 R T AX N Z IH0 Z -> M AA1 R T AX N Z ' IH0 Z
# MARTINEZ'S: M AA0 R T IY1 N EH2 Z IH0 Z -> M AA0 R T IY1 N EH2 Z ' IH0 Z
# MARTINS'S: M AA1 R T IH0 N Z IH0 Z -> M AA1 R T IH0 N Z ' IH0 Z
# MASSIMINO'S: M AE2 S IH0 M IY1 N OW0 Z -> M AE2 S IH0 M IY1 N OW0 ' Z
# MATTHEWS'S: M AE1 TH Y UW0 Z IH0 Z -> M AE1 TH Y UW0 Z ' IH0 Z
# MCALEESE'S: M AX K AX L IY1 S IY0 Z -> M AX K AX L IY1 S IY0 ' Z
# MCALEESE'S: M AX K AX L IY1 S IH0 Z -> M AX K AX L IY1 S ' IH0 Z
# MENU'S: M EH1 N UW0 Z -> M EH1 N UW0 ' Z
# MERCANTILE'S: M ER1 K AX N T IY2 L Z -> M ER1 K AX N T IY2 L ' Z
# MIDGETT'S: M IH1 JH AX T S -> M IH1 JH AX T ' S
# MILLS'S: M IH1 L Z IH0 Z -> M IH1 L Z ' IH0 Z
# MINNESOTA'S: M IH2 N AX S OW1 T AX Z -> M IH2 N AX S OW1 T AX ' Z
# MINORCO'S: M IH0 N AO1 R K AX Z -> M IH0 N AO1 R K AX ' Z
# MITTERRAND'S: M IY1 T AXR AE0 N D Z -> M IY1 T AXR AE0 N D ' Z
# MIYAZAWA'S: M IY2 AX Z AA1 W AX Z -> M IY2 AX Z AA1 W AX ' Z
# MOLPUS'S: M AO1 L P AX S IH0 S -> M AO1 L P AX S IH0 ' S
# MONSANTO'S: M AA0 N S AE1 N T OW0 Z -> M AA0 N S AE1 N T OW0 ' Z
# MONTREAL'S: M AA2 N T R IY0 AA1 L Z -> M AA2 N T R IY0 AA1 L ' Z
# MOSKATEL'S: M AO2 S K AX T EH1 L Z -> M AO2 S K AX T EH1 L ' Z
# MUL'S: M UH1 L Z -> M UH1 L ' Z
# MYERS'S: M AY1 AXR Z IH0 Z -> M AY1 AXR Z ' IH0 Z
# changed 27 entries in M.yaml
# NANTUCKET'S: N AE2 N T AH1 K IH0 T S -> N AE2 N T AH1 K IH0 T ' S
# NASHVILLE'S: N AE1 SH V IH2 L Z -> N AE1 SH V IH2 L ' Z
# NATEC'S: N EY1 T EH2 K S -> N EY1 T EH2 K ' S
# NENI'S: N EH1 N IY0 S -> N EH1 N IY0 ' S
# NEWS'S: N UW1 Z IH0 Z -> N UW1 Z ' IH0 Z
# NIKK'S: N IH1 K S -> N IH1 K ' S
# NORRIS'S: N AO1 R AX S IH0 Z -> N AO1 R AX S ' IH0 Z
# changed 7 entries in N.yaml
# ONASSIS'S: OW0 N AE1 S IH0 S IH0 S -> OW0 N AE1 S IH0 S IH0 ' S
# ONASSIS'S: OW0 N AA1 S IH0 S IH0 S -> OW0 N AA1 S IH0 S IH0 ' S
# ORGANIZATION'S: AO2 R G AX N IH0 Z EY1 SH AX N Z -> AO2 R G AX N IH0 Z EY1 SH AX N ' Z
# ORLOV'S: AO1 R L AO0 V S -> AO1 R L AO0 V ' S
# OTTAWA'S: AA1 T AX W AX Z -> AA1 T AX W AX ' Z
# OWENS'S: OW1 IH0 N Z IH0 Z -> OW1 IH0 N Z ' IH0 Z
# OZAL'S: OW0 Z AA1 L Z -> OW0 Z AA1 L ' Z
# changed 6 entries in O.yaml
# PALAU'S: P AX L AW1 UW0 Z -> P AX L AW1 UW0 ' Z
# PANTERA'S: P AA0 N T EH1 R AX Z -> P AA0 N T EH1 R AX ' Z
# PARRETTI'S: P AXR EH1 T IY0 S -> P AXR EH1 T IY0 ' S
# PERKINS'S: P ER1 K IH0 N Z IH0 Z -> P ER1 K IH0 N Z ' IH0 Z
# PETIPA'S: P EH0 T IY1 P AX Z -> P EH0 T IY1 P AX ' Z
# PHILHARMONIC'S: F IH2 L HH AA0 R M AA1 N IH0 K S -> F IH2 L HH AA0 R M AA1 N IH0 K ' S
# PHILIPS'S: F IH1 L IH0 P S IH0 Z -> F IH1 L IH0 P S ' IH0 Z
# PHILLIPS'S: F IH1 L IH0 P S IH0 Z -> F IH1 L IH0 P S ' IH0 Z
# PICKENS'S: P IH1 K AX N Z IH0 Z -> P IH1 K AX N Z ' IH0 Z
# PIES'S: P AY1 Z IH0 Z -> P AY1 Z ' IH0 Z
# PINNACLE'S: P IH1 N IH0 K AX L Z -> P IH1 N IH0 K AX L ' Z
# PITTS'S: P IH1 T S IH0 Z -> P IH1 T S ' IH0 Z
# PLAINTIFF'S: P L EY1 N T IH0 F S -> P L EY1 N T IH0 F ' S
# POLYGRAM'S: P AA1 L IY2 G R AE2 M Z -> P AA1 L IY2 G R AE2 M ' Z
# PROVIGO'S: P R OW0 V IY1 G OW0 Z -> P R OW0 V IY1 G OW0 ' Z
# PUMA'S: P Y UW1 M AX Z -> P Y UW1 M AX ' Z
# changed 16 entries in P.yaml
# QUARTERS'S: K W AO1 R T AXR Z -> K W AO1 R T AXR ' Z
# QUEBEC'S: K W IH0 B EH1 K S -> K W IH0 B EH1 K ' S
# changed 2 entries in Q.yaml
# RALSTON'S: R AA1 L S T AX N Z -> R AA1 L S T AX N ' Z
# RASPUTIN'S: R AE0 S P Y UW1 T AX N Z -> R AE0 S P Y UW1 T AX N ' Z
# RAVI'S: R AA2 V IY1 S -> R AA2 V IY1 ' S
# RAYBURN'S: R EY1 B ER2 N Z -> R EY1 B ER2 N ' Z
# REEVES'S: R IY1 V Z IH0 Z -> R IY1 V Z ' IH0 Z
# REINHART'S: R AY1 N HH AA0 R T S -> R AY1 N HH AA0 R T ' S
# RETIREE'S: R IH0 T AY2 R IY1 Z -> R IH0 T AY2 R IY1 ' Z
# REUTERS'S: R OY1 T AXR Z IH0 Z -> R OY1 T AXR Z ' IH0 Z
# REUTERS'S: R OY1 T AXR Z -> R OY1 T AXR ' Z
# REYNOLDS'S: R EH1 N AX L D Z IH0 Z -> R EH1 N AX L D Z ' IH0 Z
# RICHARDS'S: R IH1 CH AXR D Z IH0 Z -> R IH1 CH AXR D Z ' IH0 Z
# RIDGE'S: R IH1 JH IH0 S -> R IH1 JH IH0 ' S
# ROBERTS'S: R AA1 B AXR T S IH0 Z -> R AA1 B AXR T S ' IH0 Z
# ROGERS'S: R AA1 JH AXR Z IH0 Z -> R AA1 JH AXR Z ' IH0 Z
# ROLLAND'S: R OW1 L AX N D Z -> R OW1 L AX N D ' Z
# ROLLS'S: R OW1 L Z IH0 Z -> R OW1 L Z ' IH0 Z
# ROTH'S: R AA1 TH S -> R AA1 TH ' S
# ROTHMANS'S: R AO1 TH M AX N Z IH0 Z -> R AO1 TH M AX N Z ' IH0 Z
# ROTHSCHILD'S: R AO1 TH CH AY2 L D Z -> R AO1 TH CH AY2 L D ' Z
# ROX'S: R AA1 K S IH0 S -> R AA1 K S IH0 ' S
# changed 19 entries in R.yaml
# SAB'S: S AE1 B Z -> S AE1 B ' Z
# SADIE'S: S EY1 D IY0 Z -> S EY1 D IY0 ' Z
# SAENS'S: S EY1 N Z IH0 Z -> S EY1 N Z ' IH0 Z
# SAKS'S: S AE1 K S IH0 Z -> S AE1 K S ' IH0 Z
# SALINAS'S: S AX L IY1 N AX S IH0 Z -> S AX L IY1 N AX S ' IH0 Z
# SANDERS'S: S AE1 N D AXR Z IH0 Z -> S AE1 N D AXR Z ' IH0 Z
# SANDOZ'S: S AE1 N D AX Z IH0 Z -> S AE1 N D AX Z ' IH0 Z
# SAVINGS'S: S EY1 V IH0 NG Z -> S EY1 V IH0 NG ' Z
# SAVINGS'S: S EY1 V IH0 NG Z IH0 Z -> S EY1 V IH0 NG Z ' IH0 Z
# SCHERER'S: SH EH1 R AXR Z -> SH EH1 R AXR ' Z
# SEARS'S: S IH1 R Z IH0 Z -> S IH1 R Z ' IH0 Z
# SEARS'S: S IH1 R Z -> S IH1 R ' Z
# SELINAS'S: S AX L IY1 N AX S IH0 Z -> S AX L IY1 N AX S ' IH0 Z
# SHULTZ'S: SH UH1 L T S IH1 Z -> SH UH1 L T S IH1 ' Z
# SIMMONS'S: S IH1 M AX N Z IH0 Z -> S IH1 M AX N Z ' IH0 Z
# SINGAPORE'S: S IH1 NG AX P AO0 R Z -> S IH1 NG AX P AO0 R ' Z
# SIXTEEN'S: S IH2 K S T IY1 N Z -> S IH2 K S T IY1 N ' Z
# SMITHSONIAN'S: S M IH2 TH S OW1 N IY0 AX N Z -> S M IH2 TH S OW1 N IY0 AX N ' Z
# SPEAKES'S: S P IY1 K S IH0 Z -> S P IY1 K S ' IH0 Z
# SPINKS'S: S P IH1 NG K S IH0 Z -> S P IH1 NG K S ' IH0 Z
# STEARNS'S: S T ER1 N Z IH0 Z -> S T ER1 N Z ' IH0 Z
# STEINHARDT'S: S T AY1 N HH AA0 R T S -> S T AY1 N HH AA0 R T ' S
# STEPHANOPOULOS'S: S T EH2 F AX N AA1 P AX L AX S IH0 S -> S T EH2 F AX N AA1 P AX L AX S IH0 ' S
# STEPHENS'S: S T IY1 V IH0 N Z IH0 Z -> S T IY1 V IH0 N Z ' IH0 Z
# STERETT'S: S T EH1 R AX T S -> S T EH1 R AX T ' S
# STEVENS'S: S T IY1 V AX N Z IH0 Z -> S T IY1 V AX N Z ' IH0 Z
# STOCKMAN'S: S T AA1 K M AE2 N Z -> S T AA1 K M AE2 N ' Z
# SUBMARINES'S: S AH1 B M AXR IY2 N Z IH0 Z -> S AH1 B M AXR IY2 N Z ' IH0 Z
# SUBS'S: S AH1 B Z IH0 Z -> S AH1 B Z ' IH0 Z
# SUMMERS'S: S AH1 M AXR Z IH0 Z -> S AH1 M AXR Z ' IH0 Z
# SUMMOR'S: S AH1 M AXR Z -> S AH1 M AXR ' Z
# SUNDAE'S: S AH1 N D EY2 Z -> S AH1 N D EY2 ' Z
# SUPERMARKET'S: S UW1 P AXR M AA2 R K AX T S -> S UW1 P AXR M AA2 R K AX T ' S
# SUPERVISOR'S: S UW2 P AXR V AY1 Z AXR Z -> S UW2 P AXR V AY1 Z AXR ' Z
# SWINBURNE'S: S W IH1 N B AXR N Z -> S W IH1 N B AXR N ' Z
# SYBASE'S: S AY1 B EY1 S IH0 Z -> S AY1 B EY1 S ' IH0 Z
# SYNTEX'S: S IH1 N T EH0 K S IH0 Z -> S IH1 N T EH0 K S ' IH0 Z
# changed 35 entries in S.yaml
# TELEVISA'S: T EH2 L AX V IY1 Z AX Z -> T EH2 L AX V IY1 Z AX ' Z
# TELXON'S: T EH1 L Z AX N Z -> T EH1 L Z AX N ' Z
# THACKERY'S: TH AE1 K AXR IY0 Z -> TH AE1 K AXR IY0 ' Z
# THERAPISTS'S: TH EH1 R AX P IH0 S T S -> TH EH1 R AX P IH0 S T ' S
# THIRTEEN'S: TH ER1 T IY2 N Z -> TH ER1 T IY2 N ' Z
# TIMES'S: T AY1 M Z IH0 Z -> T AY1 M Z ' IH0 Z
# TODI'S: T OW1 D IY0 S -> T OW1 D IY0 ' S
# TOSCANINI'S: T AH2 S K AX N IY1 N IY0 Z -> T AH2 S K AX N IY1 N IY0 ' Z
# TOTINO'S: T AX T IY1 N OW0 Z -> T AX T IY1 N OW0 ' Z
# TOWNSHIP'S: T AW1 N SH IH2 P S -> T AW1 N SH IH2 P ' S
# TRANSAMERICA'S: T R AE2 N Z AX M EH1 R IH0 K AX Z -> T R AE2 N Z AX M EH1 R IH0 K AX ' Z
# TRANSCANADA'S: T R AE2 N Z K AE1 N AX D AX Z -> T R AE2 N Z K AE1 N AX D AX ' Z
# TRIZEC'S: T R IH1 Z EH0 K S -> T R IH1 Z EH0 K ' S
# TUCCI'S: T UW1 CH IY0 S -> T UW1 CH IY0 ' S
# TUDOR'S: T UW1 D ER0 Z -> T UW1 D ER0 ' Z
# TUSSAUD'S: T UW0 S OW1 Z -> T UW0 S OW1 ' Z
# changed 16 entries in T.yaml
# UTAH'S: Y UW1 T AA0 Z -> Y UW1 T AA0 ' Z
# changed 1 entries in U.yaml
# VANDERGRIFT'S: V AE1 N D AXR G R IH2 F T S -> V AE1 N D AXR G R IH2 F T ' S
# VERDI'S: V ER1 D IY0 Z -> V ER1 D IY0 ' Z
# VERGESH'S: V ER2 G EH1 SH IH0 S -> V ER2 G EH1 SH IH0 ' S
# VERGRESH'S: V ER2 G R EH1 SH IH0 S -> V ER2 G R EH1 SH IH0 ' S
# VESSELS'S: V EH1 S AX L Z IH0 Z -> V EH1 S AX L Z ' IH0 Z
# VINCE'S: V IH1 N S IH0 S -> V IH1 N S IH0 ' S
# VOLUME'S: V AA1 L Y AX M Z -> V AA1 L Y AX M ' Z
# changed 7 entries in V.yaml
# WARHOL'S: W AO1 HH R AO2 L Z -> W AO1 HH R AO2 L ' Z
# WASHI'S: W AA1 SH IY0 Z -> W AA1 SH IY0 ' Z
# WEISFIELD'S: W AY1 S F IY0 L D Z -> W AY1 S F IY0 L D ' Z
# WELLS'S: W EH1 L Z IH0 Z -> W EH1 L Z ' IH0 Z
# WHICH'S already has an apostrophe
# WICKES'S: W IH1 K S IH0 Z -> W IH1 K S ' IH0 Z
# WILES'S: W AY1 L Z IH0 Z -> W AY1 L Z ' IH0 Z
# WILLIAMS'S: W IH1 L Y AX M Z IH0 Z -> W IH1 L Y AX M Z ' IH0 Z
# WITNESS'S: W IH1 T N IH0 S IH0 Z -> W IH1 T N IH0 S ' IH0 Z
# WORKMEN'S: W ER1 K M AX N Z -> W ER1 K M AX N ' Z
# WORLDWIDE'S: W ER1 L D W AY2 D Z -> W ER1 L D W AY2 D ' Z
# changed 11 entries in W.yaml
# changed 0 entries in X.yaml
# changed 0 entries in Y.yaml
# ZABAR'S: Z AE1 B AA0 R Z -> Z AE1 B AA0 R ' Z
# ZAYRE'S: Z EY1 AXR Z -> Z EY1 AXR ' Z
# changed 2 entries in Z.yaml
# changed 0 entries in _other.yaml

# %%
def find_missing_apostrophes(yaml_dict):
    dictionary = yaml_dict.data
    counter = 0
    for word, value in dictionary.items():
        if "'" not in word:
            continue
        if isinstance(value, str):
            pronun: str = value
            if "'" not in pronun:
                print(f"{word} has no apostrophe")
                counter += 1
        else:
            if isinstance(value, list):
                pronun_list: List[str] = value
                pronun = pronun_list[0]
                if "'" not in pronun:
                    print(f"{word} has no apostrophe")
                    counter += 1
            elif isinstance(value, OrderedDict):
                pronun_dict: OrderedDict[str, str] = value
                pronun = pronun_dict[next(iter(pronun_dict))]
                if "'" not in pronun:
                    print(f"{word} has no apostrophe")
                    counter += 1
            else:
                raise ValueError(f"unexpected type: {type(value)}")
    return counter

# %%
base_path = Path("..") / "dictionary"
for yaml_file in YAML_FILES:
    yaml_path = base_path / yaml_file
    yaml_dict = read_yaml_file(yaml_path)
    num_changed = find_missing_apostrophes(yaml_dict)
    print(f"found {num_changed} entries in {yaml_file}")
# Out:
# found 0 entries in A.yaml
# found 0 entries in B.yaml
# found 0 entries in C.yaml
# found 0 entries in D.yaml
# found 0 entries in E.yaml
# found 0 entries in F.yaml
# found 0 entries in G.yaml
# found 0 entries in H.yaml
# found 0 entries in I.yaml
# found 0 entries in J.yaml
# found 0 entries in K.yaml
# found 0 entries in L.yaml
# found 0 entries in M.yaml
# found 0 entries in N.yaml
# found 0 entries in O.yaml
# found 0 entries in P.yaml
# found 0 entries in Q.yaml
# found 0 entries in R.yaml
# found 0 entries in S.yaml
# found 0 entries in T.yaml
# found 0 entries in U.yaml
# found 0 entries in V.yaml
# found 0 entries in W.yaml
# found 0 entries in X.yaml
# found 0 entries in Y.yaml
# found 0 entries in Z.yaml
# found 0 entries in _other.yaml
