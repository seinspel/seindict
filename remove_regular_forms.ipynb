# %%
from __future__ import annotations
from typing import Union, List, Optional, Dict, Tuple

# %%
from pathlib import Path
from collections import OrderedDict
from strictyaml import load, MapPattern, Str, Seq

# %%
schema = MapPattern(Str(), Str() | MapPattern(Str(), Str()) | Seq(Str()))

# %%
def read_yaml_file(fpath: Path):
    """Load the content of a YAML file as an ordered dictionary"""
    raw_data = fpath.open().read()
    return load(raw_data, schema)

# %%
YAML_FILES: List[str] = [
    "A.yaml",
    "B.yaml",
    "C.yaml",
    "D.yaml",
    "E.yaml",
    "F.yaml",
    "G.yaml",
    "H.yaml",
    "I.yaml",
    "J.yaml",
    "K.yaml",
    "L.yaml",
    "M.yaml",
    "N.yaml",
    "O.yaml",
    "P.yaml",
    "Q.yaml",
    "R.yaml",
    "S.yaml",
    "T.yaml",
    "U.yaml",
    "V.yaml",
    "W.yaml",
    "X.yaml",
    "Y.yaml",
    "Z.yaml",
    "_other.yaml",
]

# %%
def check_existence(dictionary, word, pronunciation):
    value = dictionary.get(word)
    if value is None:
        return False
    if isinstance(value, str):
        found_pronun: str = value
        return pronunciation == found_pronun
    elif isinstance(value, list):
        found_pronun_list: List[str] = value
        return any(pronunciation == found_pronun for found_pronun in found_pronun_list)
    elif isinstance(value, OrderedDict):
        found_pronun_dict: OrderedDict[str, str] = value
        return any(pronunciation == found_pronun for found_pronun in found_pronun_dict.values())
    else:
        raise ValueError(f"unexpected type: {type(value)}")

# %%
def is_regular_form(dictionary, word, pronun):
    # first check for possessive form because it's a more specific check this has to come first
    if word[-2:] == "'S" and (pronun[-2:] == " S" or pronun[-2:] == " Z"):
        base_word = word[:-2]
        base_pronun = pronun[:-2]
        form_name = "possessive"
    # plural forms and third-person present verbs
    elif word[-1] == "S" and (pronun[-2:] == " S" or pronun[-2:] == " Z"):
        # check if the base form exists
        base_word = word[:-1]
        base_pronun = pronun[:-2]
        form_name = "plural/third-person"
    elif word[-2:] == "ED" and (pronun[-2:] == " D" or pronun[-2:] == " T"):
        # check if the base form exists
        base_word = word[:-2]
        base_pronun = pronun[:-2]
        form_name = "simple past"
    else:
        return False
    if check_existence(dictionary, base_word, base_pronun):
        if pronun[-2:] == " S" and pronun[-4:-2] not in (" F", " K", " P", " T", "TH"):
            print(f"not a regular form: {word} ({pronun}) (base form: {base_word})")
            return False
        if pronun[-2:] == " T" and pronun[-4:-2] not in (" F", " K", " P", " S", "SH", "CH", "TH"):
            print(f"not a regular form: {word} ({pronun}) (base form: {base_word})")
            return False
        # print(f"found {form_name} form: {word} (base form: {base_word})")
        return True
    return False

# %%
def remove_regular_forms(yaml_dict):
    dictionary = yaml_dict.data
    counter = 0
    for word, value in dictionary.items():
        if isinstance(value, str):
            pronun: str = value
            if is_regular_form(dictionary, word, pronun):
                del yaml_dict[word]
                counter += 1
        else:
            if isinstance(value, list):
                pronun_list: List[str] = value
            elif isinstance(value, OrderedDict):
                pronun_dict: OrderedDict[str, str] = value
                pronun_list = list(pronun_dict.values())
            else:
                raise ValueError(f"unexpected type: {type(value)}")
                
            for pronun in pronun_list:
                if is_regular_form(dictionary, word, pronun):
                    del yaml_dict[word]
                    counter += 1
                    break  # stop looking for plural forms, we already deleted the word
    return counter

# %%
base_path = Path(".") / "dictionary"
for yaml_file in YAML_FILES:
    yaml_path = base_path / yaml_file
    yaml_dict = read_yaml_file(yaml_path)
    num_removed = remove_regular_forms(yaml_dict)
    print(f"removed {num_removed} entries in {yaml_file}")
    yaml_path.open("w").write(yaml_dict.as_yaml())
# Out:
# not a regular form: AGNES (AE1 G N IH0 S) (base form: AGNE)
# not a regular form: ALAMITOS (AE2 L AX M IY1 T OW0 S) (base form: ALAMITO)
# not a regular form: ALMOS (AA1 L M OW0 S) (base form: ALMO)
# not a regular form: ANAS (AE1 N AX S) (base form: ANA)
# not a regular form: APARTHEID'S (AX P AA1 R T AY2 D S) (base form: APARTHEID)
# not a regular form: ASTROS (AE1 S T R OW0 S) (base form: ASTRO)
# not a regular form: ATLAS (AE1 T L AX S) (base form: ATLA)
# removed 0 entries in A.yaml
# not a regular form: BERETTAS (B AXR EH1 T AX S) (base form: BERETTA)
# not a regular form: BIDCOS (B IH1 D K OW0 S) (base form: BIDCO)
# not a regular form: BIMBOS (B IH1 M B OW0 S) (base form: BIMBO)
# not a regular form: BODEGAS (B OW0 D EY1 G AX S) (base form: BODEGA)
# not a regular form: BONS (B AA1 N S) (base form: BON)
# not a regular form: BRAS (B R AA1 S) (base form: BRA)
# not a regular form: BUENOS (B W EY1 N OW0 S) (base form: BUENO)
# not a regular form: BURRITOS (B AXR IY1 T OW0 S) (base form: BURRITO)
# removed 1 entries in B.yaml
# not a regular form: CADS (K AE1 D S) (base form: CAD)
# not a regular form: CARLOS (K AA1 R L OW0 S) (base form: CARLO)
# not a regular form: CASSANDRAS (K AX S AE1 N D R AX S) (base form: CASSANDRA)
# not a regular form: CECOS (S IY1 K OW0 S) (base form: CECO)
# not a regular form: CHAPAS (CH AA1 P AX S) (base form: CHAPA)
# not a regular form: CHEERIOS (CH IH1 R IY0 OW0 S) (base form: CHEERIO)
# not a regular form: CHEVYS (SH EH1 V IY0 S) (base form: CHEVY)
# not a regular form: COLAS (K OW1 L AX S) (base form: COLA)
# not a regular form: COLINAS (K OW0 L IY1 N AX S) (base form: COLINA)
# not a regular form: CONSTANTINOS (K AA2 N S T AX N T IY1 N OW0 S) (base form: CONSTANTINO)
# not a regular form: COOS (K UW1 S) (base form: COO)
# not a regular form: CRUZADOS (K R UW2 Z AA1 D OW0 S) (base form: CRUZADO)
# removed 0 entries in C.yaml
# not a regular form: DALLAS (D AE1 L AX S) (base form: DALLA)
# not a regular form: DAS (D AA1 S) (base form: DA)
# not a regular form: DEVILLIER'S (D IH0 V IH1 L Y AXR S) (base form: DEVILLIER)
# not a regular form: DUENAS (D UW0 EH1 N AX S) (base form: DUENA)
# not a regular form: DUENAS (D W EY1 N Y AX S) (base form: DUENA)
# not a regular form: DURAN'S (D AXR AE1 N S) (base form: DURAN)
# removed 0 entries in D.yaml
# not a regular form: ELIAS (IH0 L AY1 AX S) (base form: ELIA)
# removed 0 entries in E.yaml
# not a regular form: FELLAS (F EH1 L AX S) (base form: FELLA)
# removed 0 entries in F.yaml
# not a regular form: GAMEKEEPERS (G EY1 M K IY2 P AXR S) (base form: GAMEKEEPER)
# not a regular form: GEES (JH IY1 S) (base form: GEE)
# not a regular form: GERBILS (JH ER1 B IH0 L S) (base form: GERBIL)
# not a regular form: GROHS (G R OW1 S) (base form: GROH)
# not a regular form: GROS (G R OW1 S) (base form: GRO)
# removed 0 entries in G.yaml
# not a regular form: HAHS (HH AA1 S) (base form: HAH)
# not a regular form: HAMBROS (HH AE1 M B R OW0 S) (base form: HAMBRO)
# not a regular form: HARDING'S (HH AA1 R D IH0 NG S) (base form: HARDING)
# not a regular form: HAUS (HH AW1 S) (base form: HAU)
# not a regular form: HEIDI'S (HH AY1 D IY0 S) (base form: HEIDI)
# not a regular form: HILLAS (HH IH1 L AX S) (base form: HILLA)
# not a regular form: HIMALAYAS (HH IH2 M AX L EY1 AX S) (base form: HIMALAYA)
# removed 0 entries in H.yaml
# removed 0 entries in I.yaml
# not a regular form: JONBENET'S (JH AO1 N B AX N EY1 S) (base form: JONBENET)
# removed 0 entries in J.yaml
# not a regular form: KIWANIS (K IH0 W AA1 N IH0 S) (base form: KIWANI)
# not a regular form: KONTRAS (K AA1 N T R AX S) (base form: KONTRA)
# not a regular form: KOSHERS (K OW1 SH AXR S) (base form: KOSHER)
# removed 0 entries in K.yaml
# not a regular form: LALAS (L AA1 L AX S) (base form: LALA)
# not a regular form: LAOS (L AW1 S) (base form: LAO)
# not a regular form: LAS (L AA1 S) (base form: LA)
# not a regular form: LATINOS (L AA0 T IY1 N OW0 S) (base form: LATINO)
# not a regular form: LOBOS (L OW1 B OW0 S) (base form: LOBO)
# not a regular form: LOS (L OW1 S) (base form: LO)
# not a regular form: LUCAS (L UW1 K AX S) (base form: LUCA)
# removed 0 entries in L.yaml
# not a regular form: MARCOS (M AA1 R K OW0 S) (base form: MARCO)
# not a regular form: MARDIS (M AA1 R D IY0 S) (base form: MARDI)
# not a regular form: MARIANAS (M EH2 R IY0 AE1 N AX S) (base form: MARIANA)
# not a regular form: MARIELITOS (M EH0 R IY2 EH0 L IY1 T OW0 S) (base form: MARIELITO)
# not a regular form: MARKKAS (M AA1 R K AX S) (base form: MARKKA)
# not a regular form: MARSUPIALS (M AA0 R S UW1 P IY0 AX L S) (base form: MARSUPIAL)
# not a regular form: MINAS (M IY1 N AX S) (base form: MINA)
# not a regular form: MISKITOS (M IH0 S K IY1 T OW0 S) (base form: MISKITO)
# removed 0 entries in M.yaml
# not a regular form: NARCOS (N AA1 R K OW0 S) (base form: NARCO)
# not a regular form: NAVAS (N AA1 V AX S) (base form: NAVA)
# not a regular form: NENI'S (N EH1 N IY0 S) (base form: NENI)
# not a regular form: NORIEGAS (N AO2 R IY0 EY1 G AX S) (base form: NORIEGA)
# removed 0 entries in N.yaml
# not a regular form: OLYMPIAS (OW0 L IH1 M P IY0 AX S) (base form: OLYMPIA)
# not a regular form: ORBITALS (AO1 R B IH0 T AX L S) (base form: ORBITAL)
# not a regular form: ORCAS (AO1 R K AX S) (base form: ORCA)
# not a regular form: ORLOV'S (AO1 R L AO0 V S) (base form: ORLOV)
# not a regular form: ORTEGAS (AO0 R T EY1 G AX S) (base form: ORTEGA)
# removed 0 entries in O.yaml
# not a regular form: PALLAS (P AE1 L AX S) (base form: PALLA)
# not a regular form: PAPPAS (P AE1 P AX S) (base form: PAPPA)
# not a regular form: PARRETTI'S (P AXR EH1 T IY0 S) (base form: PARRETTI)
# not a regular form: PERS (P ER1 S) (base form: PER)
# not a regular form: PERSECUTIONS (P ER2 S AX K Y UW1 SH AX N S) (base form: PERSECUTION)
# not a regular form: PICASSOS (P IH0 K AA1 S OW0 S) (base form: PICASSO)
# not a regular form: POZOS (P OW1 Z OW0 S) (base form: POZO)
# removed 0 entries in P.yaml
# removed 0 entries in Q.yaml
# not a regular form: RAMOS (R EY1 M OW0 S) (base form: RAMO)
# not a regular form: RAVI'S (R AA2 V IY1 S) (base form: RAVI)
# not a regular form: REINSPECTIONS (R IY2 IH0 N S P EH1 K SH AX N S) (base form: REINSPECTION)
# not a regular form: REPLICATORS (R EH1 P L IH0 K EY2 T AXR S) (base form: REPLICATOR)
# not a regular form: RIOS (R IY1 OW0 S) (base form: RIO)
# not a regular form: ROCCAS (R AA1 K AX S) (base form: ROCCA)
# removed 0 entries in R.yaml
# not a regular form: SANTAS (S AE1 N T AX S) (base form: SANTA)
# not a regular form: SANTOS (S AE1 N T OW0 S) (base form: SANTO)
# not a regular form: SARLOS (S AA1 R L OW0 S) (base form: SARLO)
# not a regular form: SELAS (S EH1 L AX S) (base form: SELA)
# not a regular form: SENTRAS (S EH1 N T R AX S) (base form: SENTRA)
# not a regular form: SHAS (SH AA1 S) (base form: SHA)
# not a regular form: SUPERCENTERS (S UW1 P AXR S EH2 N T AXR S) (base form: SUPERCENTER)
# not a regular form: SYNONYMS (S IH1 N AX N IH2 M S) (base form: SYNONYM)
# removed 0 entries in S.yaml
# not a regular form: TECOS (T IY1 K OW0 S) (base form: TECO)
# not a regular form: THANOS (TH AA1 N OW0 S) (base form: THANO)
# not a regular form: TREASONS (T R IY1 Z AX N S) (base form: TREASON)
# not a regular form: TUBERS (T UW1 B AXR S) (base form: TUBER)
# not a regular form: TUCCI'S (T UW1 CH IY0 S) (base form: TUCCI)
# removed 1 entries in T.yaml
# removed 1 entries in U.yaml
# not a regular form: VARGAS (V AA1 R G AX S) (base form: VARGA)
# not a regular form: VEGAS (V EY1 G AX S) (base form: VEGA)
# not a regular form: VERS (V ER1 S) (base form: VER)
# removed 0 entries in V.yaml
# not a regular form: WINOS (W IY1 N OW0 S) (base form: WINO)
# removed 0 entries in W.yaml
# removed 0 entries in X.yaml
# not a regular form: YARMULKES (Y AA1 R M AH2 L K AX S) (base form: YARMULKE)
# not a regular form: YARMULKES (Y AA1 R M AX K AX S) (base form: YARMULKE)
# not a regular form: YES (Y EH1 S) (base form: YE)
# not a regular form: YOUS (Y UW1 S) (base form: YOU)
# not a regular form: YUGOS (Y UW1 G OW0 S) (base form: YUGO)
# removed 0 entries in Y.yaml
# removed 0 entries in Z.yaml
# removed 0 entries in _other.yaml
